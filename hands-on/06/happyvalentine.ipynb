# %%
import pandas as pd
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy import sparse
import numpy as np
import re
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import pickle
import os
import json
from pathlib import Path

# %% [markdown]
# ## Develop a simple web indexer (pg 43)

# %%
class BM25(object):
    def __init__(self, fitted_vectorizer: TfidfVectorizer, b=0.75, k1=1.6):
        self.fitted_vectorizer = fitted_vectorizer
        self.b = b
        self.k1 = k1

    def fit(self, X):
        """Fit IDF to documents X"""
        self.y = super(TfidfVectorizer, self.fitted_vectorizer).transform(X)
        self.avdl = self.y.sum(1).mean()

    def transform(self, q):
        """Calculate BM25 between query q and documents X"""
        b, k1, avdl = self.b, self.k1, self.avdl

        # apply CountVectorizer
        len_y = self.y.sum(1).A1
        (q,) = super(TfidfVectorizer, self.fitted_vectorizer).transform(q)
        assert sparse.isspmatrix_csr(q)

        # convert to csc for better column slicing
        y = self.y.tocsc()[:, q.indices]
        denom = y + (k1 * (1 - b + b * len_y / avdl))[:, None]
        idf = self.fitted_vectorizer._tfidf.idf_[None, q.indices] - 1.0
        numer = y.multiply(np.broadcast_to(idf, y.shape)) * (k1 + 1)
        return (numer / denom).sum(1).A1

# %%
def custom_preprocessor(s: str):
    lemmatizer = WordNetLemmatizer()
    s = re.sub(r"[^A-Za-z]", " ", s)
    s = re.sub(r"\s+", " ", s)
    s = re.sub(" +", " ", s)
    s = s.lower()
    s = word_tokenize(s)
    s = set(s).difference(set(stopwords.words("english")))
    s = [word for word in s if len(word) > 2]
    s = [lemmatizer.lemmatize(w) for w in s]
    s = " ".join(s)
    return s

# %%
class WebIndexer:
    def __init__(self):
        self.crawled_folder = Path(os.path.abspath('')) / 'crawled/'
        self.stored_file = 'indexer/manual_indexer.pickle'
        if not Path(self.stored_file).parent.exists():
            Path.mkdir(Path(self.stored_file).parent)
        if os.path.isfile(self.stored_file):
            with open(self.stored_file, 'rb') as f:
                cached_dict = pickle.load(f)
            self.__dict__.update(cached_dict)
        else:
            self.run_indexer()
    def run_indexer(self):
        documents = []
        for file in os.listdir(self.crawled_folder):
            if file.endswith(".json"):
                try:
                    j = json.load(open(os.path.join(self.crawled_folder, file)))
                    documents.append(j)
                except json.JSONDecodeError as e:
                    print(file)
        self.documents = pd.DataFrame.from_dict(documents)
        tfidf_vectorizor = TfidfVectorizer(preprocessor=custom_preprocessor, stop_words=stopwords.words('english'))
        tfidf_vectorizor.fit(self.documents.apply(lambda s: ' '.join(s[['title', 'text']]), axis=1))
        self.bm25 = BM25(tfidf_vectorizor)
        self.bm25.fit(self.documents.apply(lambda s: ' '.join(s[['title', 'text']]), axis=1))
        with open(self.stored_file, 'wb') as f:
            pickle.dump(self.__dict__, f)
    def search(self, query):
        scores = self.bm25.transform([query])
        df = pd.DataFrame(scores, columns=["score"])
        return self.documents.join(df)

# %%
wi = WebIndexer()
res = wi.search("School")
res[res["score"] > 0].sort_values("score", ascending=False).head(20)
# Out:
#                                                      url  \
# 10679                         https://w3.grad.cmu.ac.th/
# 10281              https://service.camt.cmu.ac.th/gifted
# 8074               https://service.camt.cmu.ac.th/gifted
# 6541                          https://w3.grad.cmu.ac.th/
# 4670                          https://w3.grad.cmu.ac.th/
# 673                          https://www.grad.cmu.ac.th/
# 933                          https://www.grad.cmu.ac.th/
# 2395   https://service.camt.cmu.ac.th/gifted/gifted/i...
# 5010   https://service.camt.cmu.ac.th/gifted/gifted/i...
# 4674                             https://www.tmc.or.th/
# 3399                 https://smart.grad.cmu.ac.th/?p=101
# 605                  https://smart.grad.cmu.ac.th/?p=103
# 681                                   https://tmc.or.th/
# 3386                              https://www.tmc.or.th/
# 4574                              https://www.tmc.or.th/
# 4028                     https://www.apple.com/th/legal/
# 5485                                  https://tmc.or.th/
# 7683                     https://www.apple.com/th/legal/
# 8816                     https://www.apple.com/th/legal/
# 621                               https://www.tmc.or.th/
#
#                                                    title  \
# 10679             Graduate School, Chiang Mai University
# 10281                                   Gift School 2023
# 8074                                    Gift School 2023
# 6541              Graduate School, Chiang Mai University
# 4670              Graduate School, Chiang Mai University
# 673               Graduate School, Chiang Mai University
# 933               Graduate School, Chiang Mai University
# 2395                                    Gift School 2566
# 5010                                    Gift School 2566
# 4674          แพทยสภา :: The Medical Council of Thailand
# 3399   DASHBOARD | Graduate School, Chiang Mai Univer...
# 605    DASHBOARD | Graduate School, Chiang Mai Univer...
# 681           แพทยสภา :: The Medical Council of Thailand
# 3386          แพทยสภา :: The Medical Council of Thailand
# 4574          แพทยสภา :: The Medical Council of Thailand
# 4028                                      Apple - กฎหมาย
# 5485          แพทยสภา :: The Medical Council of Thailand
# 7683                                      Apple - กฎหมาย
# 8816                                      Apple - กฎหมาย
# 621           แพทยสภา :: The Medical Council of Thailand
#
#                                                     text  \
# 10679
# 10281  << คลิกที่นี่ >> ระบบรับสมัคร Gifted School | ...
# 8074   << คลิกที่นี่ >> ระบบรับสมัคร Gifted School | ...
# 6541
# 4670
# 673    MIdS : Multidisciplinary and Interdisciplinary...
# 933    MIdS : Multidisciplinary and Interdisciplinary...
# 2395   Login Form  เลขบัตรประชาชน 13 หลัก        ดู P...
# 5010   Login Form  เลขบัตรประชาชน 13 หลัก        ดู P...
# 4674   TMC Mail | แผนผังเว็บไซต์    TMC Mail | แผนผัง...
# 3399   Loading...       Toggle navigation Graduate  D...
# 605    Loading...       Toggle navigation Graduate  D...
# 681    X ปิดหน้านี้                                  ...
# 3386   X ปิดหน้านี้                                  ...
# 4574   X ปิดหน้านี้                                  ...
# 4028   Apple ร้าน Mac iPad iPhone Watch AirPods TV แล...
# 5485   X ปิดหน้านี้                                  ...
# 7683   Apple ร้าน Mac iPad iPhone Watch AirPods TV แล...
# 8816   Apple ร้าน Mac iPad iPhone Watch AirPods TV แล...
# 621    X ปิดหน้านี้                                  ...
#
#                                                url_lists     score
# 10679                                                 []  5.454879
# 10281  [https://service.camt.cmu.ac.th/gifted/gifted/...  5.454879
# 8074   [https://service.camt.cmu.ac.th/gifted/gifted/...  5.454879
# 6541                                                  []  5.454879
# 4670                                                  []  5.454879
# 673    [https://cmu.to/admission/, https://w3.grad.cm...  5.313894
# 933    [https://cmu.to/admission/, https://w3.grad.cm...  5.313894
# 2395                                                  []  5.259520
# 5010                                                  []  5.259520
# 4674   [https://tmc.or.th/, https://tmc.or.th/En, htt...  5.028001
# 3399   [https://www.med.cmu.ac.th/web/, https://www.m...  4.979293
# 605    [https://www.med.cmu.ac.th/web/, https://www.m...  4.931520
# 681    [https://tmc.or.th/, https://tmc.or.th/En, htt...  4.907976
# 3386   [https://tmc.or.th/, https://tmc.or.th/En, htt...  4.907976
# 4574   [https://tmc.or.th/, https://tmc.or.th/En, htt...  4.907976
# 4028   [https://www.med.cmu.ac.th/th/, https://www.me...  4.907976
# 5485   [https://tmc.or.th/, https://tmc.or.th/En, htt...  4.907976
# 7683   [https://www.med.cmu.ac.th/th/, https://www.me...  4.907976
# 8816   [https://www.med.cmu.ac.th/th/, https://www.me...  4.907976
# 621    [https://tmc.or.th/, https://tmc.or.th/En, htt...  4.907976

# %%
wi.search("medicine").sort_values("score", ascending=False).drop("url_lists", axis=1).head(20)
# Out:
#                                                     url  \
# 4698            https://www.facebook.com/BiochemMedCmu/
# 1600            https://www.facebook.com/BiochemMedCmu/
# 4292  https://www.facebook.com/nationallibraryofmedi...
# 8904                https://www.youtube.com/user/NLMNIH
# 7560         https://w2.med.cmu.ac.th/hcss/topics/news/
# 3314              https://www.youtube.com/@emergencycmu
# 2635                        http://www.thaipedlung.org/
# 1268              https://www.youtube.com/@emergencycmu
# 6645                    https://www.facebook.com/emcmu/
# 6081                        http://www.thaipedlung.org/
# 7763                    https://www.facebook.com/emcmu/
# 6009  https://forms.gle/AmMWffm3WNkpgy1G7?fbclid=IwA...
# 903   https://www.facebook.com/MDCMU?__cft__[0]=AZUc...
# 6045           https://w2.med.cmu.ac.th/hcss/news/7677/
# 3142                      https://w2.med.cmu.ac.th/sso/
# 7063                      https://w2.med.cmu.ac.th/sso/
# 1113                      https://w2.med.cmu.ac.th/sso/
# 1849  https://w1.med.cmu.ac.th/pr/personnel/agency-s...
# 2071  https://w1.med.cmu.ac.th/pr/personnel/agency-s...
# 5125               https://www.med.cmu.ac.th/en/backend
#
#                                                   title  \
# 4698                          Biochemistry Medicine CMU
# 1600                          Biochemistry Medicine CMU
# 4292                 National Library of Medicine (NLM)
# 8904             National Library of Medicine - YouTube
# 7560  ประชาสัมพันธ์ – งานบริการกลางโรงพยาบาล โรงพยาบ...
# 3314                   Emergency Medicine CMU - YouTube
# 2635  สมาคมโรคระบบหายใจและเวชบำบัดวิกฤตในเด็ก :: Ped...
# 1268                   Emergency Medicine CMU - YouTube
# 6645    EMERGENCY MEDICINE DEPARTMENT, CMU | Chiang Mai
# 6081  สมาคมโรคระบบหายใจและเวชบำบัดวิกฤตในเด็ก :: Ped...
# 7763    EMERGENCY MEDICINE DEPARTMENT, CMU | Chiang Mai
# 6009  ลงทะเบียนผู้เข้าร่วมงาน  "Frontiers in Transla...
# 903   Faculty of Medicine, Chiang Mai University | M...
# 6045  ต้อนรับแพทย์จากภาควิชาเวชศาสตร์ชุมชน คณะแพทยศา...
# 3142  ::: คณะแพทยศาสตร์ มหาวิทยาลัยเชียงใหม่  ::: Ch...
# 7063  ::: คณะแพทยศาสตร์ มหาวิทยาลัยเชียงใหม่  ::: Ch...
# 1113  ::: คณะแพทยศาสตร์ มหาวิทยาลัยเชียงใหม่  ::: Ch...
# 1849          หน่วยวารสารและโรงพิมพ์ – งานประชาสัมพันธ์
# 2071                หมวดติดต่อสอบถาม – งานประชาสัมพันธ์
# 5125  เข้าสู่ระบบ ‹ Faculty of Medicine Chiang Mai U...
#
#                                                    text     score
# 4698                                                     2.972423
# 1600                                                     2.972423
# 4292                                                     2.956566
# 8904  เกี่ยวกับ สื่อ ลิขสิทธิ์ ติดต่อเรา ครีเอเตอร์ ...  2.925355
# 7560  หน้าหลัก  เกี่ยวกับเรา   ผู้บริหาร  โครงสร้างห...  2.925355
# 3314  เกี่ยวกับ สื่อ ลิขสิทธิ์ ติดต่อเรา ครีเอเตอร์ ...  2.925355
# 2635                                                     2.925355
# 1268  เกี่ยวกับ สื่อ ลิขสิทธิ์ ติดต่อเรา ครีเอเตอร์ ...  2.925355
# 6645                                                     2.925355
# 6081                                                     2.925355
# 7763                                                     2.925355
# 6009  ลงทะเบียนผู้เข้าร่วมงาน  " Frontiers in Transl...  2.925355
# 903                                                      2.925355
# 6045  หน้าหลัก  เกี่ยวกับเรา   ผู้บริหาร  โครงสร้างห...  2.909995
# 3142        เข้าสู่หน้าหลัก             เข้าสู่หน้าหลัก  2.894796
# 7063        เข้าสู่หน้าหลัก             เข้าสู่หน้าหลัก  2.894796
# 1113        เข้าสู่หน้าหลัก             เข้าสู่หน้าหลัก  2.894796
# 1849  หน้าแรก  วิสัยทัศน์-พันธกิจ  โครงสร้างหน่วยงาน...  2.879755
# 2071  หน้าแรก  วิสัยทัศน์-พันธกิจ  โครงสร้างหน่วยงาน...  2.879755
# 5125  สร้างขึ้นโดยใช้ WordPress    ชื่อผู้ใช้หรือที่...  2.879755

# %% [markdown]
# ## Elastic search tutorial (pg 50 - 58)
# - +oEqEIt7p6lC_=rI1HIC
# - eyJ2ZXIiOiI4LjEyLjEiLCJhZHIiOlsiMTcyLjE4LjAuMjo5MjAwIl0sImZnciI6IjNiYmJmMzc3MmY0OWFmMDVlNjZmOTI2NjBjYjUxMWZmZDVkZTY3ODg4M2U0ODgzYTEzNjlmNDEzOTcyYmYwZDQiLCJrZXkiOiJlRE54bkkwQlhKX3FRMUFkSU1FNzpoNzlSSXphV1FIU0pQVWRhRldMckZnIn0=

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch("https://localhost:9200", basic_auth=("elastic", "+oEqEIt7p6lC_=rI1HIC"), ca_certs="./http_ca.crt")
es.info()
# Out:
# ObjectApiResponse({'name': '30bfd7881813', 'cluster_name': 'docker-cluster', 'cluster_uuid': 'o_7sMfofS_G5l-SWN2IbUA', 'version': {'number': '8.12.1', 'build_flavor': 'default', 'build_type': 'docker', 'build_hash': '6185ba65d27469afabc9bc951cded6c17c21e3f3', 'build_date': '2024-02-01T13:07:13.727175297Z', 'build_snapshot': False, 'lucene_version': '9.9.2', 'minimum_wire_compatibility_version': '7.17.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'You Know, for Search'})

# %%
class ElasticIndexer:
    def __init__(self):
        self.crawled_folder = Path(os.path.abspath("")) / "crawled/"
        with open(self.crawled_folder / "url_list.pickle", "rb") as f:
            self.file_mapper = pickle.load(f)
        self.es_client = Elasticsearch(
            "https://localhost:9200",
            basic_auth=("elastic", "+oEqEIt7p6lC_=rI1HIC"),
            ca_certs="./http_ca.crt",
        )

    def run_indexer(self):
        self.es_client.options(ignore_status=400).indices.create(index="simple")
        self.es_client.options(ignore_status=[400, 404]).indices.delete(index="simple")
        for file in os.listdir(self.crawled_folder):
            if file.endswith(".json"):
                try:
                    j = json.load(open(os.path.join(self.crawled_folder, file)))
                    j["id"] = j["url"]
                    self.es_client.index(index="simple", document=j)
                except json.JSONDecodeError as e:
                    print(file)

# %%
ei = ElasticIndexer()
ei.run_indexer()
# Out:
# 2310681883848955003.json
# 7886801698163828316.json

# %%
query = {"bool": {"must": [{"match": {"text": "apply"}}]}}
results = ei.es_client.search(index="simple", query=query)
print("Got %d Hits:" % results["hits"]["total"]["value"])
for hit in results["hits"]["hits"]:
    print(
        "The title is '{0} ({1})'.".format(
            hit["_source"]["title"], hit["_source"]["url"]
        )
    )
# Out:
# Got 360 Hits:
# The title is 'DASHBOARD | Graduate School, Chiang Mai University (https://smart.grad.cmu.ac.th/?p=curr)'.
# The title is 'Pricing  |  Compute Engine: Virtual Machines (VMs)  |  Google Cloud (https://cloud.google.com/compute/all-pricing/)'.
# The title is 'NON-IMMIGRANT “B” - International Relations Unit (https://w1.med.cmu.ac.th/foreign/en/non-immigrant-b/)'.
# The title is 'YouTube TV - Watch & DVR Live Sports, Shows & News (https://tv.youtube.com/?utm_source=gaboutpage&utm_medium=youtubetv&utm_campaign=gabout)'.
# The title is 'YouTube TV - Watch & DVR Live Sports, Shows & News (https://tv.youtube.com/welcome/?zipcode=78702)'.
# The title is 'YouTube TV - Watch & DVR Live Sports, Shows & News (https://tv.youtube.com/)'.
# The title is 'YouTube Research - Home (https://research.youtube/)'.
# The title is 'NON-IMMIGRANT “ED” - International Relations Unit (https://w1.med.cmu.ac.th/foreign/en/non-immigrant-ed/)'.
# The title is 'FAQ. - CMU - Graduate School (https://www.grad.cmu.ac.th/grad_wp2/?page_id=2707)'.
# The title is 'Think you're ready to make money on YouTube? Take this quiz!  - YouTube Blog (https://blog.youtube/inside-youtube/are-you-ready-to-make-money-on-youtube/)'.

# %%
query = {"regexp": {"text": ".*vision.*"}}
results = ei.es_client.search(index="simple", query=query)
print("Got %d Hits:" % results["hits"]["total"]["value"])
for hit in results["hits"]["hits"]:
    print(
        "The title is '{0} ({1})'.".format(
            hit["_source"]["title"], hit["_source"]["url"]
        )
    )
# Out:
# Got 1159 Hits:
# The title is 'ระเบียบและประกาศมหาวิทยาลัยเชียงใหม่ (https://camt.cmu.ac.th/index.php/en/th/serviceview/121b0f9c-32c8-416f-bf9c-47c1dba82af3)'.
# The title is 'The Department of Microbiology welcomed visiting students from Biomedical Laboratory Science, UCL University College - ภาควิชาจุลชีววิทยา (https://w1.med.cmu.ac.th/microb/the-department-of-microbiology-welcomed-visiting-students-from-biomedical-laboratory-science-ucl-university-college/)'.
# The title is 'Business Intelligence Modernization  |  Google Cloud (https://cloud.google.com/solutions/business-intelligence/)'.
# The title is 'History - Faculty of Medicine Chiang Mai University (https://www.med.cmu.ac.th/en/about-us/history/)'.
# The title is 'Cloud Composer | Google Cloud (https://cloud.google.com/composer/)'.
# The title is 'Automate with AI-powered translation | Google Cloud (https://cloud.google.com/translate/)'.
# The title is 'à¸ªà¸³à¸à¸±à¸à¸à¸±à¸à¸à¸²à¸à¸¸à¸à¸ à¸²à¸à¸à¸²à¸£à¸¨à¸¶à¸à¸©à¸² à¸¡à¸«à¸²à¸§à¸´à¸à¸¢à¸²à¸¥à¸±à¸¢à¹à¸à¸µà¸¢à¸à¹à¸«à¸¡à¹ (http://eqd.cmu.ac.th/)'.
# The title is 'Google For Families Help (https://support.google.com/families#topic=7327495)'.
# The title is 'Current Students - Department of Biochemistry (https://w1.med.cmu.ac.th/biochem/current-students/)'.
# The title is 'Home (https://camt.cmu.ac.th/index.php/en/#does_google_know_my_location_ans)'.

# %% [markdown]
# ## manual_index flask app (pg 59)
# see indexer_server.py

# %%
import requests
import json

query="exam"

# %%
json.loads(requests.get(f"http://127.0.0.1:5000/search_es?query={query}").text)
# Out:
# {'elapse': 0.07343411445617676,
#  'results': [{'score': 12.686181,
#    'text': 'Skip to content    คู่มือสำหรับนักศึกษา หมวดหมู่รวบรวมคู่มือการใช้การอุปกรณ์ต่างๆสำหรับนักศึกษา     ',
#    'title': 'คู่มือสำหรับนักศึกษา - ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC)',
#    'url': 'https://w2.med.cmu.ac.th/mtec/topics/manual/manuals-for-students-manual/'},
#   {'score': 12.686181,
#    'text': 'Skip to content    คู่มือสำหรับนักศึกษา หมวดหมู่รวบรวมคู่มือการใช้การอุปกรณ์ต่างๆสำหรับนักศึกษา     ',
#    'title': 'คู่มือสำหรับนักศึกษา - ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC)',
#    'url': 'https://w2.med.cmu.ac.th/mtec/topics/manual/manuals-for-students-manual/'},
#   {'score': 11.916158,
#    'text': 'Department of Biochemistry  +66-53-935-322  Mon-Fr 08.30-16.30                             Home  Abo',
#    'title': 'INTERNATIONAL PROGRAM - Department of Biochemistry',
#    'url': 'https://w1.med.cmu.ac.th/biochem/international-program/'},
#   {'score': 11.916158,
#    'text': 'Department of Biochemistry  +66-53-935-322  Mon-Fr 08.30-16.30                             Home  Abo',
#    'title': 'INTERNATIONAL PROGRAM - Department of Biochemistry',
#    'url': 'https://w1.med.cmu.ac.th/biochem/international-program/'},
#   {'score': 11.883339,
#    'text': 'Skip to content    คู่มือสำหรับอาจารย์ หมวดหมู่รวบรวมคู่มือการใช้การอุปกรณ์ต่างๆสำหรับอาจารย์       ',
#    'title': 'คู่มือสำหรับอาจารย์ - ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC)',
#    'url': 'https://w2.med.cmu.ac.th/mtec/topics/manual/manuals-for-teachers-manual/'},
#   {'score': 11.883339,
#    'text': 'Skip to content    คู่มือสำหรับเจ้าหน้าที่ หมวดหมู่รวบรวมคู่มือการใช้การอุปกรณ์ต่างๆสำหรับเจ้าหน้าที',
#    'title': 'คู่มือสำหรับเจ้าหน้าที่ - ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC)',
#    'url': 'https://w2.med.cmu.ac.th/mtec/topics/manual/manuals-for-employees-manual/'},
#   {'score': 11.883339,
#    'text': 'top of page Teaching and Learning Innovation Center ศูนย์นวัตกรรมการสอนและการเรียนรู้ มหาวิทยาลัยเชี',
#    'title': 'Covid-19 Response Research | TLIC - Teaching and Learning Innovation Center, CMU',
#    'url': 'https://www.info.tlic.cmu.ac.th/covid-19-response-reseach'},
#   {'score': 11.883339,
#    'text': 'Skip to content    คู่มือสำหรับเจ้าหน้าที่ หมวดหมู่รวบรวมคู่มือการใช้การอุปกรณ์ต่างๆสำหรับเจ้าหน้าที',
#    'title': 'คู่มือสำหรับเจ้าหน้าที่ - ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC)',
#    'url': 'https://w2.med.cmu.ac.th/mtec/topics/manual/manuals-for-employees-manual/'},
#   {'score': 11.883339,
#    'text': 'Skip to content    คู่มือสำหรับอาจารย์ หมวดหมู่รวบรวมคู่มือการใช้การอุปกรณ์ต่างๆสำหรับอาจารย์       ',
#    'title': 'คู่มือสำหรับอาจารย์ - ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC)',
#    'url': 'https://w2.med.cmu.ac.th/mtec/topics/manual/manuals-for-teachers-manual/'},
#   {'score': 9.994889,
#    'text': 'Skip to content                  Home  Current Students   Undergraduate Students  Graduate Students ',
#    'title': 'Undergraduate Students – Registration Office Chiang Mai University',
#    'url': 'https://www.reg.cmu.ac.th/webreg/en/undergraduate-students/'},
#   {'score': 9.994889,
#    'text': 'Skip to content                  Home  Current Students   Undergraduate Students  Graduate Students ',
#    'title': 'Undergraduate Students – Registration Office Chiang Mai University',
#    'url': 'https://www.reg.cmu.ac.th/webreg/undergraduate-students/'},
#   {'score': 9.879158,
#    'text': 'Skip to content       ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC)  Medical Technology Education Center ',
#    'title': 'ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC) - คู่มือการใช้งาน',
#    'url': 'https://w2.med.cmu.ac.th/mtec/manuals-for-users/'},
#   {'score': 9.879158,
#    'text': 'Skip to content       ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC)  Medical Technology Education Center ',
#    'title': 'ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC) - คู่มือการใช้งาน',
#    'url': 'https://w2.med.cmu.ac.th/mtec/manuals-for-users/'},
#   {'score': 8.793592,
#    'text': "This website uses Cookies. Click Accept to agree to our website's cookie use as described in our Pri",
#    'title': 'Home - Google Cloud Community',
#    'url': 'https://www.googlecloudcommunity.com/'},
#   {'score': 8.430315,
#    'text': 'โทร.053-935533  ภาควิชาศัลยศาสตร์ คณะแพทยศาสตร์ มหาวิทยาลัยเชียงใหม่ หน้าหลัก เกี่ยวกับภาควิชา โครงส',
#    'title': 'หน่วยศัลยศาสตร์ทรวงอก หัวใจและหลอดเลือด - Surgery CMU',
#    'url': 'https://w1.med.cmu.ac.th/surgery/personnel/cvt/'},
#   {'score': 8.430315,
#    'text': 'โทร.053-935533  ภาควิชาศัลยศาสตร์ คณะแพทยศาสตร์ มหาวิทยาลัยเชียงใหม่ หน้าหลัก เกี่ยวกับภาควิชา โครงส',
#    'title': 'หน่วยศัลยศาสตร์ทรวงอก หัวใจและหลอดเลือด - Surgery CMU',
#    'url': 'https://w1.med.cmu.ac.th/surgery/personnel/cvt/'},
#   {'score': 8.287804,
#    'text': 'Overview    close     Accelerate your digital transformation  Whether your business is early in its ',
#    'title': 'Google Cloud Innovators Plus',
#    'url': 'https://cloud.google.com/innovators/innovatorsplus/'},
#   {'score': 8.160612,
#    'text': 'HOME  MOU  PROGRAMS   Postgraduate Programs  Elective Preceptorship for International Students  Clin',
#    'title': 'VISA / WORK PERMIT - International Relations Unit',
#    'url': 'https://w1.med.cmu.ac.th/foreign/en/visa-work-permit/'},
#   {'score': 6.497631,
#    'text': 'help_outline Support Sign in home Home workspaces Recommended for Google Workspace arrow_right assis',
#    'title': 'Download Business Apps in Marketplace | Google Workspace',
#    'url': 'https://workspace.google.com/marketplace/'},
#   {'score': 6.386247,
#    'text': "Page Contents Register now for Google Cloud Next '24 in Las Vegas April 9-11 to take advantage of ea",
#    'title': 'Google Cloud Learning Courses and Certifications | Google Cloud',
#    'url': 'https://cloud.google.com/learn/'},
#   {'score': 6.034414,
#    'text': "Register now for Google Cloud Next '24 in Las Vegas April 9-11. Google Cloud Certification Demonstra",
#    'title': 'Certifications | Google Cloud',
#    'url': 'https://cloud.google.com/certification/'},
#   {'score': 6.034414,
#    'text': "Register now for Google Cloud Next '24 in Las Vegas April 9-11. Google Cloud Certification Demonstra",
#    'title': 'Certifications | Google Cloud',
#    'url': 'https://cloud.google.com/learn/certification'},
#   {'score': 5.761804,
#    'text': "Register now for Google Cloud Next '24 in Las Vegas April 9-11 to take advantage of early bird prici",
#    'title': 'Google Cloud Courses and Training | Google Cloud',
#    'url': 'https://cloud.google.com/training/'},
#   {'score': 5.761804,
#    'text': "Register now for Google Cloud Next '24 in Las Vegas April 9-11 to take advantage of early bird prici",
#    'title': 'Google Cloud Courses and Training | Google Cloud',
#    'url': 'https://cloud.google.com/learn/training/'},
#   {'score': 0.2431078,
#    'text': 'Skip to Content Quizzes PRO  Courses  Guides New   Tech Help Pro  Expert Videos  About wikiHow Pro  ',
#    'title': 'wikiHow Experts',
#    'url': 'https://www.wikihow.com/Experts'}],
#  'status': 'success',
#  'total_hit': 25}

# %%
json.loads(requests.get(f"http://127.0.0.1:5000/search_manual?query={query}").text)
# Out:
# {'elapse': 0.03786039352416992,
#  'results': [{'score': 9.847685939571612,
#    'text': 'หน้าหลัก  บุคลากร  หลักสูตร – เกณฑ์แพทยสภา  สำหรับนักศึกษา   คู่มือ นศพ.  กระบวนวิชา   นศพ. ปี 1  นศพ. ปี 2  นศพ. ปี 3    ดาวน์โหลด  ประเมิน    สำหรับอาจารย์-ภาควิชา  ดาวน์โหลด  ติดต่อเรา                      คณะแพทยศาสตร์                                 หน้าหลัก  บุคลากร  หลักสูตร – เกณฑ์แพทยสภา  สำหรับนักศึกษา   คู่มือ นศพ.  กระบวนวิชา   นศพ. ปี 1  นศพ. ปี 2  นศพ. ปี 3    ดาวน์โหลด  ประเมิน    สำหรับอาจารย์-ภาควิชา  ดาวน์โหลด  ติดต่อเรา                         คำสั่ง/ประกาศ คู่มือกระบวนวิชาฯ รายชื่อนักศึกษาแพทย์ ดาวน์โหลด สำหรับอาจารย์-ภาควิชา อาจารย์ผู้สอนประเมินนักศึกษา คำสั่ง/ประกาศ    ⇒ คำสั่งแต่งตั้งคณะกรรมการกระบวนวิชาในหลักสูตรแพทยศาส
ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC)  Medical Technology Education Center     หน้าหลัก  ข่าวสาร   ข่าวประชาสัมพันธ์ด้าน IT    เกี่ยวกับ   เกี่ยวกับ MTEC  เครือข่ายร่วมสอน    ภาพกิจกรรม  บริการ   รูปแบบการให้บริการ   การให้บริการ ZOOM    ดาวน์โหลด    ผลงาน  คู่มือ   คู่มือสำหรับนักศึกษา  คู่มือสำหรับอาจารย์  คู่มือสำหรับเจ้าหน้าที่    FAQ  ติดต่อศูนย์  ขอใช้บริการ             Search for:      Search       Slide Out Sidebar                            ประเภทการใช้งาน                        อุปกรณ์             Microsoft Teams  แอปพลิเคชันสำหรับการสื่อสาร ที่สะดวกต่อการทำงานร่วมกัน               Zoom  แอปพลิเคชันสำหรับการสื่อสาร ที่สะดวกต่อการประชุมออนไลน์อย่างง่าย               Exam Plus  แพลตฟอร์มทำข้อสอบออนไลน์ ทั้งใช้งานง่ายและปลอดภัย               MANGO Canvas  ระบบ LMS ใหม่ล่าสุดจากศูนย์ TLIC               WebEx Meeting  แอปพลิเคชันสำหรับการสื่อสาร รองรับผู้เข้าร่วมจำนวนมาก               Canva  แพลตฟอร์มสร้างสื่อหลากหลายรูปแบบ สามารถใช้งานได้ง่าย ทุกที่และทุกเวลา        ลักษณะการใช้งาน             ห้องเรียนจำลอง               การสอบ               สื่อการสอน                                                © 2024 Powered By MTEC. All Rights Reserved. | Design by ITERU                 MTEC      หน้าหลัก  ข่าวสาร   ข่าวประชาสัมพันธ์ด้าน IT    เกี่ยวกับ   เกี่ยวกับ MTEC  เครือข่ายร่วมสอน    ภาพกิจกรรม  บริการ   รูปแบบการให้บริการ   การให้บริการ ZOOM    ดาวน์โหลด    ผลงาน  คู่มือ   คู่มือสำหรับนักศึกษา  คู่มือสำหรับอาจารย์  คู่มือสำหรับเจ้าหน้าที่    FAQ  ติดต่อศูนย์  ขอใช้บริการ     เข้าสู่ระบบ',
#    'title': 'ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC) - คู่มือการใช้งาน',
#    'url': 'https://w2.med.cmu.ac.th/mtec/manuals-for-users/'},
#   {'score': 9.52169075845295,
#    'text': 'Skip to content       ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC)  Medical Technology Education Center     หน้าหลัก  ข่าวสาร   ข่าวประชาสัมพันธ์ด้าน IT    เกี่ยวกับ   เกี่ยวกับ MTEC  เครือข่ายร่วมสอน    ภาพกิจกรรม  บริการ   รูปแบบการให้บริการ   การให้บริการ ZOOM    ดาวน์โหลด    ผลงาน  คู่มือ   คู่มือสำหรับนักศึกษา  คู่มือสำหรับอาจารย์  คู่มือสำหรับเจ้าหน้าที่    FAQ  ติดต่อศูนย์  ขอใช้บริการ             Search for:      Search       Slide Out Sidebar                            ประเภทการใช้งาน                        อุปกรณ์             Microsoft Teams  แอปพลิเคชันสำหรับการสื่อสาร ที่สะดวกต่อการทำงานร่วมกัน               Zoom  แอปพลิเคชันสำหรับการสื่อสาร ที่สะดวกต่อการประชุมออนไลน์อย่างง่าย               Exam Plus  แพลตฟอร์มทำข้อสอบออนไลน์ ทั้งใช้งานง่ายและปลอดภัย               MANGO Canvas  ระบบ LMS ใหม่ล่าสุดจากศูนย์ TLIC               WebEx Meeting  แอปพลิเคชันสำหรับการสื่อสาร รองรับผู้เข้าร่วมจำนวนมาก               Canva  แพลตฟอร์มสร้างสื่อหลากหลายรูปแบบ สามารถใช้งานได้ง่าย ทุกที่และทุกเวลา        ลักษณะการใช้งาน             ห้องเรียนจำลอง               การสอบ               สื่อการสอน                                                © 2024 Powered By MTEC. All Rights Reserved. | Design by ITERU                 MTEC      หน้าหลัก  ข่าวสาร   ข่าวประชาสัมพันธ์ด้าน IT    เกี่ยวกับ   เกี่ยวกับ MTEC  เครือข่ายร่วมสอน    ภาพกิจกรรม  บริการ   รูปแบบการให้บริการ   การให้บริการ ZOOM    ดาวน์โหลด    ผลงาน  คู่มือ   คู่มือสำหรับนักศึกษา  คู่มือสำหรับอาจารย์  คู่มือสำหรับเจ้าหน้าที่    FAQ  ติดต่อศูนย์  ขอใช้บริการ     เข้าสู่ระบบ',
#    'title': 'ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC) - คู่มือการใช้งาน',
#    'url': 'https://w2.med.cmu.ac.th/mtec/manuals-for-users/'},
#   {'score': 9.216587299190296,
#    'text': 'Skip to content    คู่มือสำหรับนักศึกษา หมวดหมู่รวบรวมคู่มือการใช้การอุปกรณ์ต่างๆสำหรับนักศึกษา       ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC)  Medical Technology Education Center     หน้าหลัก  ข่าวสาร   ข่าวประชาสัมพันธ์ด้าน IT    เกี่ยวกับ   เกี่ยวกับ MTEC  เครือข่ายร่วมสอน    ภาพกิจกรรม  บริการ   รูปแบบการให้บริการ   การให้บริการ ZOOM    ดาวน์โหลด    ผลงาน  คู่มือ   คู่มือสำหรับนักศึกษา  คู่มือสำหรับอาจารย์  คู่มือสำหรับเจ้าหน้าที่    FAQ  ติดต่อศูนย์  ขอใช้บริการ             Search for:      Search       Slide Out Sidebar                      วิธีตั้งค่า iPad สำหรับใช้งาน Exam Pod บน iOS 17   26 กันยายน 2023 26 กันยายน 2023 in Exam Plus , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือการใช้อุปกรณ์ , คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่     ในวันที่ 18 กันยายน 2566 ที่ผ่านมา ทาง Apple ได้ทำการปล่อยอัปเดต iOS 17 ทำให้เกิดผลกระทบต่อการใช้งาน Exam Pod ทำให้อุปกรณ์ iPad เกิดความไม่เสถียร โดยทางผู้พัฒนาแอปพลิเคชั่น Exam Pod ได้แนะนำให้ผู้ใช้งานทำการปิด Guided Access บนอุปกรณ์ iPad เพื่อแก้ไขปัญหาดังกล่าว ซึ่งในบทความนี้จะมีคู่มือสอนวิธีการตั้งค่าทั้งแบบย่อและแบบละเอียด                สร้างลิงค์แบบสั้นและ QR CODE ด้วย cmu.to   2 กุมภาพันธ์ 2023 2 กุมภาพันธ์ 2023 in คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , คู่มืออื่นๆ     cmu.to เป็นเครื่องมือสำหรับอำนวยความสะดวกอย่างหนึ่งของทางมหาวิทยาลัยเชียงใหม่ที่ทำขึ้นเพื่อมาแก้ไขปัญหาด้านนี้ โดยท่านสามารถนำ Link ที่ต้องการแชร์มาลดความยาวลงและกำหนดเป็นชื่อตามที่ต้องการได้เช่นกัน                Microsoft Teams Portal   1 เมษายน 2022 28 มีนาคม 2023 in Microsoft Teams , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานเบื้องต้น     Microsoft Teams เป็นหนึ่งในผลิตภัณฑ์ของ Microsoft เหมาะสำหรับใช้ในการประสานงานภายในทีม หน่วยงาน แผนก ศูนย์ ภาคขนาดเล็ก ผู้ใช้งานสามารถเลือกชมหัวข้อที่ต้องการ โดยการคลิกบนชื่อหัวข้อเพื่อเข้าชม                วิธีออกจากระบบ Microsoft Teams โดยไม่ให้ Account ตกค้าง   21 กุมภาพันธ์ 2022 in Microsoft Teams , ข่าวสาร , ข่าวเทคโนโลยีดิจิทัล , คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป , ระดับผู้ใช้งานเบื้องต้น     ทางศูนย์ MTEC จึงขอเสนอวิธีการออกจากระบบโดยไม่ให้บัญชี Microsoft ของท่านตกค้างในอุปกรณ์ หลังจากใช้งาน Microsoft Teams ในอุปกรณ์ทั้งของส่วนบุคคลและส่วนกลาง                วิธีการบันทึกไฟล์ Word เป็น PDF โดยเลี่ยงไม่ให้อักษรเคลื่อน   2 กุมภาพันธ์ 2022 2 กุมภาพันธ์ 2022 in คู่มือการใช้งาน , คู่มือการใช้อุปกรณ์ , คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , คู่มืออื่นๆ , ระดับผู้ใช้งานเบื้องต้น     รวมวิธีการแปลงไฟล์เอกสารใน Microsoft Words เป็นไฟล์ PDF โดยเลี่ยงไม่ให้อักษรเกิดการเคลื่อนที่จนผิดเพี้ยนจากไฟล์ต้นฉบับ                Q&A   17 พฤศจิกายน 2021 17 พฤศจิกายน 2021 in Exam Plus , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือสำหรับนักศึกษา     คำถามที่พบบ่อยขณะใช้งาน Exam Pod ในส่วนนี้จะมีอัปเดทอย่างสม่ำเสมอตามเสียงตอบรับของผู้ใช้งาน                วิธีแก้ปัญหาเบื้องต้น   17 พฤศจิกายน 2021 26 กันยายน 2023 in Exam Plus , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือสำหรับนักศึกษา     วิธีการแก้ปัญหาเบื้องต้นหากนักศึกษาพบเจอปัญหาขณะสอบออนไลน์                ขั้นตอนการเข้าสอบออนไลน์ ด้วย Exam Pod   17 พฤศจิกายน 2021 24 พฤศจิกายน 2021 in Exam Plus , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือสำหรับนักศึกษา     คู่มือแนะนำเบื้องต้นสำหรับนักศึกษาคณะแพทยศาสตร์ที่ใช้ Exam Pod ในการสอบออนไลน์                วิธีการตั้งค่าไมโครโฟนบนอุปกรณ์ต่างๆ   3 พฤศจิกายน 2021 3 พฤศจิกายน 2021 in คู่มือการใช้งาน , คู่มือการใช้อุปกรณ์ , คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป , ระดับผู้ใช้งานเบื้องต้น , ไม่มีหมวดหมู่     เมื่อทราบรูปแบบการทำงานของไมโครโฟนแต่ละรูปแบบแล้ว ต่อไปจะเป็นการตั้งค่าบนอุปกรณ์ที่เชื่อมต่อและบนแอพลิเคชั่นที่ใช้ติดต่อเป็นหลัก                รูปแบบการทำงานและคุณภาพของไมโครโฟน   1 พฤศจิกายน 2021 3 พฤศจิกายน 2021 in คู่มือการใช้งาน , คู่มือการใช้อุปกรณ์ , คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำ ...
#    'title': 'คู่มือสำหรับนักศึกษา - ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC)',
#    'url': 'https://w2.med.cmu.ac.th/mtec/topics/manual/manuals-for-students-manual/'},
#   {'score': 9.216587299190296,
#    'text': 'Skip to content    คู่มือสำหรับนักศึกษา หมวดหมู่รวบรวมคู่มือการใช้การอุปกรณ์ต่างๆสำหรับนักศึกษา       ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC)  Medical Technology Education Center     หน้าหลัก  ข่าวสาร   ข่าวประชาสัมพันธ์ด้าน IT    เกี่ยวกับ   เกี่ยวกับ MTEC  เครือข่ายร่วมสอน    ภาพกิจกรรม  บริการ   รูปแบบการให้บริการ   การให้บริการ ZOOM    ดาวน์โหลด    ผลงาน  คู่มือ   คู่มือสำหรับนักศึกษา  คู่มือสำหรับอาจารย์  คู่มือสำหรับเจ้าหน้าที่    FAQ  ติดต่อศูนย์  ขอใช้บริการ             Search for:      Search       Slide Out Sidebar                      วิธีตั้งค่า iPad สำหรับใช้งาน Exam Pod บน iOS 17   26 กันยายน 2023 26 กันยายน 2023 in Exam Plus , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือการใช้อุปกรณ์ , คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่     ในวันที่ 18 กันยายน 2566 ที่ผ่านมา ทาง Apple ได้ทำการปล่อยอัปเดต iOS 17 ทำให้เกิดผลกระทบต่อการใช้งาน Exam Pod ทำให้อุปกรณ์ iPad เกิดความไม่เสถียร โดยทางผู้พัฒนาแอปพลิเคชั่น Exam Pod ได้แนะนำให้ผู้ใช้งานทำการปิด Guided Access บนอุปกรณ์ iPad เพื่อแก้ไขปัญหาดังกล่าว ซึ่งในบทความนี้จะมีคู่มือสอนวิธีการตั้งค่าทั้งแบบย่อและแบบละเอียด                สร้างลิงค์แบบสั้นและ QR CODE ด้วย cmu.to   2 กุมภาพันธ์ 2023 2 กุมภาพันธ์ 2023 in คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , คู่มืออื่นๆ     cmu.to เป็นเครื่องมือสำหรับอำนวยความสะดวกอย่างหนึ่งของทางมหาวิทยาลัยเชียงใหม่ที่ทำขึ้นเพื่อมาแก้ไขปัญหาด้านนี้ โดยท่านสามารถนำ Link ที่ต้องการแชร์มาลดความยาวลงและกำหนดเป็นชื่อตามที่ต้องการได้เช่นกัน                Microsoft Teams Portal   1 เมษายน 2022 28 มีนาคม 2023 in Microsoft Teams , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานเบื้องต้น     Microsoft Teams เป็นหนึ่งในผลิตภัณฑ์ของ Microsoft เหมาะสำหรับใช้ในการประสานงานภายในทีม หน่วยงาน แผนก ศูนย์ ภาคขนาดเล็ก ผู้ใช้งานสามารถเลือกชมหัวข้อที่ต้องการ โดยการคลิกบนชื่อหัวข้อเพื่อเข้าชม                วิธีออกจากระบบ Microsoft Teams โดยไม่ให้ Account ตกค้าง   21 กุมภาพันธ์ 2022 in Microsoft Teams , ข่าวสาร , ข่าวเทคโนโลยีดิจิทัล , คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป , ระดับผู้ใช้งานเบื้องต้น     ทางศูนย์ MTEC จึงขอเสนอวิธีการออกจากระบบโดยไม่ให้บัญชี Microsoft ของท่านตกค้างในอุปกรณ์ หลังจากใช้งาน Microsoft Teams ในอุปกรณ์ทั้งของส่วนบุคคลและส่วนกลาง                วิธีการบันทึกไฟล์ Word เป็น PDF โดยเลี่ยงไม่ให้อักษรเคลื่อน   2 กุมภาพันธ์ 2022 2 กุมภาพันธ์ 2022 in คู่มือการใช้งาน , คู่มือการใช้อุปกรณ์ , คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , คู่มืออื่นๆ , ระดับผู้ใช้งานเบื้องต้น     รวมวิธีการแปลงไฟล์เอกสารใน Microsoft Words เป็นไฟล์ PDF โดยเลี่ยงไม่ให้อักษรเกิดการเคลื่อนที่จนผิดเพี้ยนจากไฟล์ต้นฉบับ                Q&A   17 พฤศจิกายน 2021 17 พฤศจิกายน 2021 in Exam Plus , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือสำหรับนักศึกษา     คำถามที่พบบ่อยขณะใช้งาน Exam Pod ในส่วนนี้จะมีอัปเดทอย่างสม่ำเสมอตามเสียงตอบรับของผู้ใช้งาน                วิธีแก้ปัญหาเบื้องต้น   17 พฤศจิกายน 2021 26 กันยายน 2023 in Exam Plus , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือสำหรับนักศึกษา     วิธีการแก้ปัญหาเบื้องต้นหากนักศึกษาพบเจอปัญหาขณะสอบออนไลน์                ขั้นตอนการเข้าสอบออนไลน์ ด้วย Exam Pod   17 พฤศจิกายน 2021 24 พฤศจิกายน 2021 in Exam Plus , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือสำหรับนักศึกษา     คู่มือแนะนำเบื้องต้นสำหรับนักศึกษาคณะแพทยศาสตร์ที่ใช้ Exam Pod ในการสอบออนไลน์                วิธีการตั้งค่าไมโครโฟนบนอุปกรณ์ต่างๆ   3 พฤศจิกายน 2021 3 พฤศจิกายน 2021 in คู่มือการใช้งาน , คู่มือการใช้อุปกรณ์ , คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป , ระดับผู้ใช้งานเบื้องต้น , ไม่มีหมวดหมู่     เมื่อทราบรูปแบบการทำงานของไมโครโฟนแต่ละรูปแบบแล้ว ต่อไปจะเป็นการตั้งค่าบนอุปกรณ์ที่เชื่อมต่อและบนแอพลิเคชั่นที่ใช้ติดต่อเป็นหลัก                รูปแบบการทำงานและคุณภาพของไมโครโฟน   1 พฤศจิกายน 2021 3 พฤศจิกายน 2021 in คู่มือการใช้งาน , คู่มือการใช้อุปกรณ์ , คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำ ...
#    'title': 'คู่มือสำหรับนักศึกษา - ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC)',
#    'url': 'https://w2.med.cmu.ac.th/mtec/topics/manual/manuals-for-students-manual/'},
#   {'score': 8.736674407635574,
#    'text': 'Skip to content    คู่มือสำหรับเจ้าหน้าที่ หมวดหมู่รวบรวมคู่มือการใช้การอุปกรณ์ต่างๆสำหรับเจ้าหน้าที่       ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC)  Medical Technology Education Center     หน้าหลัก  ข่าวสาร   ข่าวประชาสัมพันธ์ด้าน IT    เกี่ยวกับ   เกี่ยวกับ MTEC  เครือข่ายร่วมสอน    ภาพกิจกรรม  บริการ   รูปแบบการให้บริการ   การให้บริการ ZOOM    ดาวน์โหลด    ผลงาน  คู่มือ   คู่มือสำหรับนักศึกษา  คู่มือสำหรับอาจารย์  คู่มือสำหรับเจ้าหน้าที่    FAQ  ติดต่อศูนย์  ขอใช้บริการ             Search for:      Search       Slide Out Sidebar                      พบกับ New Microsoft Teams หน้าตาคล้ายเดิมเพิ่มเติมคือความลื่น   21 พฤศจิกายน 2023 in Microsoft Teams , ข่าวสาร , ข่าวเทคโนโลยีดิจิทัล , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป     ในวันที่ 27 มีนาคม 2566 ที่ผ่านนี้ ทาง Microsoft ได้ปล่อยตัวอย่างวิดิโอเพื่อประชาสัมพันธ์ Update ใหม่ที่กำลังจะลงให้กับ Microsoft Teams โดยใช้ชื่อ Welcome to the New Era of Microsoft Teams                วิธีตั้งค่า iPad สำหรับใช้งาน Exam Pod บน iOS 17   26 กันยายน 2023 26 กันยายน 2023 in Exam Plus , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือการใช้อุปกรณ์ , คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่     ในวันที่ 18 กันยายน 2566 ที่ผ่านมา ทาง Apple ได้ทำการปล่อยอัปเดต iOS 17 ทำให้เกิดผลกระทบต่อการใช้งาน Exam Pod ทำให้อุปกรณ์ iPad เกิดความไม่เสถียร โดยทางผู้พัฒนาแอปพลิเคชั่น Exam Pod ได้แนะนำให้ผู้ใช้งานทำการปิด Guided Access บนอุปกรณ์ iPad เพื่อแก้ไขปัญหาดังกล่าว ซึ่งในบทความนี้จะมีคู่มือสอนวิธีการตั้งค่าทั้งแบบย่อและแบบละเอียด                แนะนำ FEATURES ใหม่ที่น่าสนใจ ของ MICROSOFT TEAMS Education (อัปเดตวันที่ 8/5/2023)   11 พฤษภาคม 2023 26 พฤษภาคม 2023 in Microsoft Teams , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป     ในวันที่ 8 พฤษภาคม 2566 ที่ผ่านนี้ ทาง Microsoft Teams Education ได้ทำการอัปเดตการใช้งาน เพื่อช่วยอำนวยความสะดวกสำหรับผู้ใช้งาน Microsoft Teams สำหรับใช้ในทางด้านการศึกษา                Welcome to the New Era of Microsoft Teams อัปเดตใหญ่ใน Microsoft Teams   28 มีนาคม 2023 2 ตุลาคม 2023 in Microsoft Teams , ข่าวสาร , ข่าวเทคโนโลยีดิจิทัล , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป     ในวันที่ 27 มีนาคม 2566 ที่ผ่านนี้ ทาง Microsoft ได้ปล่อยตัวอย่างวิดิโอเพื่อประชาสัมพันธ์ Update ใหม่ที่กำลังจะลงให้กับ Microsoft Teams โดยใช้ชื่อ Welcome to the New Era of Microsoft Teams                สร้างลิงค์แบบสั้นและ QR CODE ด้วย cmu.to   2 กุมภาพันธ์ 2023 2 กุมภาพันธ์ 2023 in คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , คู่มืออื่นๆ     cmu.to เป็นเครื่องมือสำหรับอำนวยความสะดวกอย่างหนึ่งของทางมหาวิทยาลัยเชียงใหม่ที่ทำขึ้นเพื่อมาแก้ไขปัญหาด้านนี้ โดยท่านสามารถนำ Link ที่ต้องการแชร์มาลดความยาวลงและกำหนดเป็นชื่อตามที่ต้องการได้เช่นกัน                Microsoft Teams Portal   1 เมษายน 2022 28 มีนาคม 2023 in Microsoft Teams , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานเบื้องต้น     Microsoft Teams เป็นหนึ่งในผลิตภัณฑ์ของ Microsoft เหมาะสำหรับใช้ในการประสานงานภายในทีม หน่วยงาน แผนก ศูนย์ ภาคขนาดเล็ก ผู้ใช้งานสามารถเลือกชมหัวข้อที่ต้องการ โดยการคลิกบนชื่อหัวข้อเพื่อเข้าชม                วิธีลงทะเบียนและขอรับสิทธิ์ Zoom Basic ด้วย CMU Account   16 มีนาคม 2022 in Zoom Meetings , ข่าวประชาสัมพันธ์ , ข่าวสาร , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป     ในขณะนี้ทางคณะแพทยศาสตร์มหาวิทยาลัยเชียงใหม่ได้เพิ่มโควต้าสำหรับขอรับสิทธิ์ Zoom Pro License ให้แก่อาจารย์ผู้สอน โดยเปิดโอกาสให้อาจารย์ที่ประสงค์ใช้งาน สามารถลงทะเบียนได้ด้วยตนเอง                วิธีการเปิดใช้งาน Poll ใน Zoom Meeting   3 มีนาคม 2022 in Zoom Meetings , ข่าวประชาสัมพันธ์ , ข่าวสาร , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป     วิธีการใช้งาน Polls บน Zoom สำหรับผู้ใช้งานที่จำเป็นต้องการแบบสอบถามหรือข้อสอบสั้นๆบน Zoom                วิธีออกจากระบบ Microsoft Teams โดยไม่ให้ Account ตกค้าง   21 ก ...
#    'title': 'คู่มือสำหรับเจ้าหน้าที่ - ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC)',
#    'url': 'https://w2.med.cmu.ac.th/mtec/topics/manual/manuals-for-employees-manual/'},
#   {'score': 8.736674407635574,
#    'text': 'Skip to content    คู่มือสำหรับเจ้าหน้าที่ หมวดหมู่รวบรวมคู่มือการใช้การอุปกรณ์ต่างๆสำหรับเจ้าหน้าที่       ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC)  Medical Technology Education Center     หน้าหลัก  ข่าวสาร   ข่าวประชาสัมพันธ์ด้าน IT    เกี่ยวกับ   เกี่ยวกับ MTEC  เครือข่ายร่วมสอน    ภาพกิจกรรม  บริการ   รูปแบบการให้บริการ   การให้บริการ ZOOM    ดาวน์โหลด    ผลงาน  คู่มือ   คู่มือสำหรับนักศึกษา  คู่มือสำหรับอาจารย์  คู่มือสำหรับเจ้าหน้าที่    FAQ  ติดต่อศูนย์  ขอใช้บริการ             Search for:      Search       Slide Out Sidebar                      พบกับ New Microsoft Teams หน้าตาคล้ายเดิมเพิ่มเติมคือความลื่น   21 พฤศจิกายน 2023 in Microsoft Teams , ข่าวสาร , ข่าวเทคโนโลยีดิจิทัล , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป     ในวันที่ 27 มีนาคม 2566 ที่ผ่านนี้ ทาง Microsoft ได้ปล่อยตัวอย่างวิดิโอเพื่อประชาสัมพันธ์ Update ใหม่ที่กำลังจะลงให้กับ Microsoft Teams โดยใช้ชื่อ Welcome to the New Era of Microsoft Teams                วิธีตั้งค่า iPad สำหรับใช้งาน Exam Pod บน iOS 17   26 กันยายน 2023 26 กันยายน 2023 in Exam Plus , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือการใช้อุปกรณ์ , คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่     ในวันที่ 18 กันยายน 2566 ที่ผ่านมา ทาง Apple ได้ทำการปล่อยอัปเดต iOS 17 ทำให้เกิดผลกระทบต่อการใช้งาน Exam Pod ทำให้อุปกรณ์ iPad เกิดความไม่เสถียร โดยทางผู้พัฒนาแอปพลิเคชั่น Exam Pod ได้แนะนำให้ผู้ใช้งานทำการปิด Guided Access บนอุปกรณ์ iPad เพื่อแก้ไขปัญหาดังกล่าว ซึ่งในบทความนี้จะมีคู่มือสอนวิธีการตั้งค่าทั้งแบบย่อและแบบละเอียด                แนะนำ FEATURES ใหม่ที่น่าสนใจ ของ MICROSOFT TEAMS Education (อัปเดตวันที่ 8/5/2023)   11 พฤษภาคม 2023 26 พฤษภาคม 2023 in Microsoft Teams , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป     ในวันที่ 8 พฤษภาคม 2566 ที่ผ่านนี้ ทาง Microsoft Teams Education ได้ทำการอัปเดตการใช้งาน เพื่อช่วยอำนวยความสะดวกสำหรับผู้ใช้งาน Microsoft Teams สำหรับใช้ในทางด้านการศึกษา                Welcome to the New Era of Microsoft Teams อัปเดตใหญ่ใน Microsoft Teams   28 มีนาคม 2023 2 ตุลาคม 2023 in Microsoft Teams , ข่าวสาร , ข่าวเทคโนโลยีดิจิทัล , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป     ในวันที่ 27 มีนาคม 2566 ที่ผ่านนี้ ทาง Microsoft ได้ปล่อยตัวอย่างวิดิโอเพื่อประชาสัมพันธ์ Update ใหม่ที่กำลังจะลงให้กับ Microsoft Teams โดยใช้ชื่อ Welcome to the New Era of Microsoft Teams                สร้างลิงค์แบบสั้นและ QR CODE ด้วย cmu.to   2 กุมภาพันธ์ 2023 2 กุมภาพันธ์ 2023 in คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , คู่มืออื่นๆ     cmu.to เป็นเครื่องมือสำหรับอำนวยความสะดวกอย่างหนึ่งของทางมหาวิทยาลัยเชียงใหม่ที่ทำขึ้นเพื่อมาแก้ไขปัญหาด้านนี้ โดยท่านสามารถนำ Link ที่ต้องการแชร์มาลดความยาวลงและกำหนดเป็นชื่อตามที่ต้องการได้เช่นกัน                Microsoft Teams Portal   1 เมษายน 2022 28 มีนาคม 2023 in Microsoft Teams , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานเบื้องต้น     Microsoft Teams เป็นหนึ่งในผลิตภัณฑ์ของ Microsoft เหมาะสำหรับใช้ในการประสานงานภายในทีม หน่วยงาน แผนก ศูนย์ ภาคขนาดเล็ก ผู้ใช้งานสามารถเลือกชมหัวข้อที่ต้องการ โดยการคลิกบนชื่อหัวข้อเพื่อเข้าชม                วิธีลงทะเบียนและขอรับสิทธิ์ Zoom Basic ด้วย CMU Account   16 มีนาคม 2022 in Zoom Meetings , ข่าวประชาสัมพันธ์ , ข่าวสาร , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป     ในขณะนี้ทางคณะแพทยศาสตร์มหาวิทยาลัยเชียงใหม่ได้เพิ่มโควต้าสำหรับขอรับสิทธิ์ Zoom Pro License ให้แก่อาจารย์ผู้สอน โดยเปิดโอกาสให้อาจารย์ที่ประสงค์ใช้งาน สามารถลงทะเบียนได้ด้วยตนเอง                วิธีการเปิดใช้งาน Poll ใน Zoom Meeting   3 มีนาคม 2022 in Zoom Meetings , ข่าวประชาสัมพันธ์ , ข่าวสาร , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป     วิธีการใช้งาน Polls บน Zoom สำหรับผู้ใช้งานที่จำเป็นต้องการแบบสอบถามหรือข้อสอบสั้นๆบน Zoom                วิธีออกจากระบบ Microsoft Teams โดยไม่ให้ Account ตกค้าง   21 ก ...
#    'title': 'คู่มือสำหรับเจ้าหน้าที่ - ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC)',
#    'url': 'https://w2.med.cmu.ac.th/mtec/topics/manual/manuals-for-employees-manual/'},
#   {'score': 8.736674407635574,
#    'text': 'Skip to content    คู่มือสำหรับอาจารย์ หมวดหมู่รวบรวมคู่มือการใช้การอุปกรณ์ต่างๆสำหรับอาจารย์       ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC)  Medical Technology Education Center     หน้าหลัก  ข่าวสาร   ข่าวประชาสัมพันธ์ด้าน IT    เกี่ยวกับ   เกี่ยวกับ MTEC  เครือข่ายร่วมสอน    ภาพกิจกรรม  บริการ   รูปแบบการให้บริการ   การให้บริการ ZOOM    ดาวน์โหลด    ผลงาน  คู่มือ   คู่มือสำหรับนักศึกษา  คู่มือสำหรับอาจารย์  คู่มือสำหรับเจ้าหน้าที่    FAQ  ติดต่อศูนย์  ขอใช้บริการ             Search for:      Search       Slide Out Sidebar                      พบกับ New Microsoft Teams หน้าตาคล้ายเดิมเพิ่มเติมคือความลื่น   21 พฤศจิกายน 2023 in Microsoft Teams , ข่าวสาร , ข่าวเทคโนโลยีดิจิทัล , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป     ในวันที่ 27 มีนาคม 2566 ที่ผ่านนี้ ทาง Microsoft ได้ปล่อยตัวอย่างวิดิโอเพื่อประชาสัมพันธ์ Update ใหม่ที่กำลังจะลงให้กับ Microsoft Teams โดยใช้ชื่อ Welcome to the New Era of Microsoft Teams                วิธีตั้งค่า iPad สำหรับใช้งาน Exam Pod บน iOS 17   26 กันยายน 2023 26 กันยายน 2023 in Exam Plus , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือการใช้อุปกรณ์ , คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่     ในวันที่ 18 กันยายน 2566 ที่ผ่านมา ทาง Apple ได้ทำการปล่อยอัปเดต iOS 17 ทำให้เกิดผลกระทบต่อการใช้งาน Exam Pod ทำให้อุปกรณ์ iPad เกิดความไม่เสถียร โดยทางผู้พัฒนาแอปพลิเคชั่น Exam Pod ได้แนะนำให้ผู้ใช้งานทำการปิด Guided Access บนอุปกรณ์ iPad เพื่อแก้ไขปัญหาดังกล่าว ซึ่งในบทความนี้จะมีคู่มือสอนวิธีการตั้งค่าทั้งแบบย่อและแบบละเอียด                แนะนำ FEATURES ใหม่ที่น่าสนใจ ของ MICROSOFT TEAMS Education (อัปเดตวันที่ 8/5/2023)   11 พฤษภาคม 2023 26 พฤษภาคม 2023 in Microsoft Teams , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป     ในวันที่ 8 พฤษภาคม 2566 ที่ผ่านนี้ ทาง Microsoft Teams Education ได้ทำการอัปเดตการใช้งาน เพื่อช่วยอำนวยความสะดวกสำหรับผู้ใช้งาน Microsoft Teams สำหรับใช้ในทางด้านการศึกษา                Welcome to the New Era of Microsoft Teams อัปเดตใหญ่ใน Microsoft Teams   28 มีนาคม 2023 2 ตุลาคม 2023 in Microsoft Teams , ข่าวสาร , ข่าวเทคโนโลยีดิจิทัล , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป     ในวันที่ 27 มีนาคม 2566 ที่ผ่านนี้ ทาง Microsoft ได้ปล่อยตัวอย่างวิดิโอเพื่อประชาสัมพันธ์ Update ใหม่ที่กำลังจะลงให้กับ Microsoft Teams โดยใช้ชื่อ Welcome to the New Era of Microsoft Teams                สร้างลิงค์แบบสั้นและ QR CODE ด้วย cmu.to   2 กุมภาพันธ์ 2023 2 กุมภาพันธ์ 2023 in คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , คู่มืออื่นๆ     cmu.to เป็นเครื่องมือสำหรับอำนวยความสะดวกอย่างหนึ่งของทางมหาวิทยาลัยเชียงใหม่ที่ทำขึ้นเพื่อมาแก้ไขปัญหาด้านนี้ โดยท่านสามารถนำ Link ที่ต้องการแชร์มาลดความยาวลงและกำหนดเป็นชื่อตามที่ต้องการได้เช่นกัน                Microsoft Teams Portal   1 เมษายน 2022 28 มีนาคม 2023 in Microsoft Teams , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานเบื้องต้น     Microsoft Teams เป็นหนึ่งในผลิตภัณฑ์ของ Microsoft เหมาะสำหรับใช้ในการประสานงานภายในทีม หน่วยงาน แผนก ศูนย์ ภาคขนาดเล็ก ผู้ใช้งานสามารถเลือกชมหัวข้อที่ต้องการ โดยการคลิกบนชื่อหัวข้อเพื่อเข้าชม                วิธีลงทะเบียนและขอรับสิทธิ์ Zoom Basic ด้วย CMU Account   16 มีนาคม 2022 in Zoom Meetings , ข่าวประชาสัมพันธ์ , ข่าวสาร , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป     ในขณะนี้ทางคณะแพทยศาสตร์มหาวิทยาลัยเชียงใหม่ได้เพิ่มโควต้าสำหรับขอรับสิทธิ์ Zoom Pro License ให้แก่อาจารย์ผู้สอน โดยเปิดโอกาสให้อาจารย์ที่ประสงค์ใช้งาน สามารถลงทะเบียนได้ด้วยตนเอง                วิธีการเปิดใช้งาน Poll ใน Zoom Meeting   3 มีนาคม 2022 in Zoom Meetings , ข่าวประชาสัมพันธ์ , ข่าวสาร , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป     วิธีการใช้งาน Polls บน Zoom สำหรับผู้ใช้งานที่จำเป็นต้องการแบบสอบถามหรือข้อสอบสั้นๆบน Zoom                วิธีออกจากระบบ Microsoft Teams โดยไม่ให้ Account ตกค้าง   21 กุมภาพันธ ...
#    'title': 'คู่มือสำหรับอาจารย์ - ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC)',
#    'url': 'https://w2.med.cmu.ac.th/mtec/topics/manual/manuals-for-teachers-manual/'},
#   {'score': 8.736674407635574,
#    'text': 'Skip to content    คู่มือสำหรับอาจารย์ หมวดหมู่รวบรวมคู่มือการใช้การอุปกรณ์ต่างๆสำหรับอาจารย์       ศูนย์พัฒนาเทคโนโลยีแพทยศาสตรศึกษา (MTEC)  Medical Technology Education Center     หน้าหลัก  ข่าวสาร   ข่าวประชาสัมพันธ์ด้าน IT    เกี่ยวกับ   เกี่ยวกับ MTEC  เครือข่ายร่วมสอน    ภาพกิจกรรม  บริการ   รูปแบบการให้บริการ   การให้บริการ ZOOM    ดาวน์โหลด    ผลงาน  คู่มือ   คู่มือสำหรับนักศึกษา  คู่มือสำหรับอาจารย์  คู่มือสำหรับเจ้าหน้าที่    FAQ  ติดต่อศูนย์  ขอใช้บริการ             Search for:      Search       Slide Out Sidebar                      พบกับ New Microsoft Teams หน้าตาคล้ายเดิมเพิ่มเติมคือความลื่น   21 พฤศจิกายน 2023 in Microsoft Teams , ข่าวสาร , ข่าวเทคโนโลยีดิจิทัล , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป     ในวันที่ 27 มีนาคม 2566 ที่ผ่านนี้ ทาง Microsoft ได้ปล่อยตัวอย่างวิดิโอเพื่อประชาสัมพันธ์ Update ใหม่ที่กำลังจะลงให้กับ Microsoft Teams โดยใช้ชื่อ Welcome to the New Era of Microsoft Teams                วิธีตั้งค่า iPad สำหรับใช้งาน Exam Pod บน iOS 17   26 กันยายน 2023 26 กันยายน 2023 in Exam Plus , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือการใช้อุปกรณ์ , คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่     ในวันที่ 18 กันยายน 2566 ที่ผ่านมา ทาง Apple ได้ทำการปล่อยอัปเดต iOS 17 ทำให้เกิดผลกระทบต่อการใช้งาน Exam Pod ทำให้อุปกรณ์ iPad เกิดความไม่เสถียร โดยทางผู้พัฒนาแอปพลิเคชั่น Exam Pod ได้แนะนำให้ผู้ใช้งานทำการปิด Guided Access บนอุปกรณ์ iPad เพื่อแก้ไขปัญหาดังกล่าว ซึ่งในบทความนี้จะมีคู่มือสอนวิธีการตั้งค่าทั้งแบบย่อและแบบละเอียด                แนะนำ FEATURES ใหม่ที่น่าสนใจ ของ MICROSOFT TEAMS Education (อัปเดตวันที่ 8/5/2023)   11 พฤษภาคม 2023 26 พฤษภาคม 2023 in Microsoft Teams , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป     ในวันที่ 8 พฤษภาคม 2566 ที่ผ่านนี้ ทาง Microsoft Teams Education ได้ทำการอัปเดตการใช้งาน เพื่อช่วยอำนวยความสะดวกสำหรับผู้ใช้งาน Microsoft Teams สำหรับใช้ในทางด้านการศึกษา                Welcome to the New Era of Microsoft Teams อัปเดตใหญ่ใน Microsoft Teams   28 มีนาคม 2023 2 ตุลาคม 2023 in Microsoft Teams , ข่าวสาร , ข่าวเทคโนโลยีดิจิทัล , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป     ในวันที่ 27 มีนาคม 2566 ที่ผ่านนี้ ทาง Microsoft ได้ปล่อยตัวอย่างวิดิโอเพื่อประชาสัมพันธ์ Update ใหม่ที่กำลังจะลงให้กับ Microsoft Teams โดยใช้ชื่อ Welcome to the New Era of Microsoft Teams                สร้างลิงค์แบบสั้นและ QR CODE ด้วย cmu.to   2 กุมภาพันธ์ 2023 2 กุมภาพันธ์ 2023 in คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , คู่มืออื่นๆ     cmu.to เป็นเครื่องมือสำหรับอำนวยความสะดวกอย่างหนึ่งของทางมหาวิทยาลัยเชียงใหม่ที่ทำขึ้นเพื่อมาแก้ไขปัญหาด้านนี้ โดยท่านสามารถนำ Link ที่ต้องการแชร์มาลดความยาวลงและกำหนดเป็นชื่อตามที่ต้องการได้เช่นกัน                Microsoft Teams Portal   1 เมษายน 2022 28 มีนาคม 2023 in Microsoft Teams , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือสำหรับนักศึกษา , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานเบื้องต้น     Microsoft Teams เป็นหนึ่งในผลิตภัณฑ์ของ Microsoft เหมาะสำหรับใช้ในการประสานงานภายในทีม หน่วยงาน แผนก ศูนย์ ภาคขนาดเล็ก ผู้ใช้งานสามารถเลือกชมหัวข้อที่ต้องการ โดยการคลิกบนชื่อหัวข้อเพื่อเข้าชม                วิธีลงทะเบียนและขอรับสิทธิ์ Zoom Basic ด้วย CMU Account   16 มีนาคม 2022 in Zoom Meetings , ข่าวประชาสัมพันธ์ , ข่าวสาร , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป     ในขณะนี้ทางคณะแพทยศาสตร์มหาวิทยาลัยเชียงใหม่ได้เพิ่มโควต้าสำหรับขอรับสิทธิ์ Zoom Pro License ให้แก่อาจารย์ผู้สอน โดยเปิดโอกาสให้อาจารย์ที่ประสงค์ใช้งาน สามารถลงทะเบียนได้ด้วยตนเอง                วิธีการเปิดใช้งาน Poll ใน Zoom Meeting   3 มีนาคม 2022 in Zoom Meetings , ข่าวประชาสัมพันธ์ , ข่าวสาร , คู่มือการใช้งาน , คู่มือการใช้ระบบ , คู่มือสำหรับอาจารย์ , คู่มือสำหรับเจ้าหน้าที่ , ระดับผู้ใช้งานทั่วไป     วิธีการใช้งาน Polls บน Zoom สำหรับผู้ใช้งานที่จำเป็นต้องการแบบสอบถามหรือข้อสอบสั้นๆบน Zoom                วิธีออกจากระบบ Microsoft Teams โดยไม่ให้ Account ตกค้าง   21 กุมภาพันธ ...
ุนอาจารย์ ทุน AI                            New! CMU 21st & ทุน ABC Learning Innovation Research E-books CMU21st Articles & News About TLIC About Us Our Team Organization Chart Mission Vision Performance Contact Us TLIC Help Center Contact TLIC Work with us Internship More Use tab to navigate through the menu items. Covid-19 Response Research วิจัยถอดบทเรียนการจัดการ เรียนการสอนออนไลน์ ช่วงถานการณ์ Covid-19 ถอดบทเรียน 1 ปีกับ COVID-19  เราได้เรียนรู้อะไรบ้าง ? จากความคิดเห็นของ อาจารย์และนักศึกษา มช. มากกว่า 1,000 คน การนำเสนอผลโครงการวิจัยถอดบทเรียนการจัดการเรียนการสอนในรูปแบบออนไลน์ ในช่วงสถานการณ์การแพร่ระบาดไวรัส Covid-19\xa0 ของมหาวิทยาลัยเชียงใหม่  \u200b  รวมถึง การนำเสนอประเด็นที่น่าสนใจที่ได้จากการวิจัย และแนวทางที่สามารถนำไปปรับใช้กับการสอนออนไลน์ ที่มาจากข้อมูลจริงพร้อมทั้ง การแลกเปลี่ยนเรียนรู้ และการพูดคุยเพื่อเสนอความคิดเห็นร่วมกัน ในวันพุธที่ 9 มิถุนายน 2564 ที่ผ่านมา ผ่านช่องทาง Zoom meeting    ถอดเป็นรายงานโครงการวิจัยถอดบทเรียนการจัดการเรียนการสอนในรูปแบบออนไลน์ในช่วงสถานการณ์การแพร่ระบาดไวรัส Covid-19 ของมหาวิทยาลัยเชียงใหม่ดังนี้ รายงานฉบับสมบูรณ์ (PDF)      (กดเพื่อดาวน์โหลด) Executive Summary จากผลการสำรวจ และการวิจัยสามารถทำให้มองเห็นถึงการปรับตัวในทุกมิติของการจัดการเรียนการสอน  ในบริบทต่างๆ ที่เกี่ยวข้อง และนำไปสู่การปรับเปลี่ยนเพื่อการพัฒนาการเรียนการสอนก้าวต่อไปดังนี้ มิติการเรียนการสอน  • ใช้การเรียนแบบออนไลน์ ผ่านระบบประชุมออนไลน์ และ LMS เป็นสำคัญและมีการจัดทำสื่อออนไลน์มากขึ้น • การสอนปฏิบัติการถูกเลื่อน, การทดลองผ่านระบบออนไลน์และทำเองที่บ้านหรือจำกัดจำนวนในการเข้าห้องปฏิบัติการ  \u200b  มิติการจัดกิจกรรมนักศึกษา  • กิจกรรมส่วนใหญ่ถูกงดหรือยกเลิก • กิจกรรมที่จำเป็นและยังคงต้องจัด เปลี่ยนเป็นรูปแบบออนไลน์ • กิจกรรมที่จำเป็นดำเนินการในรูปแบบออนไลน์  \u200b  มิติการวัดและประเมินผล  • มีความกังวลเรื่องการทุจริตในการสอบออนไลน์ • การเลื่อนการสอน• ลดสัดส่วนคะแนนสอบลงโดยเปลี่ยนเป็นการให้งานนักศึกษาเพิ่มมากขึ้นเป็นการทดแทน มิติของการจัดการความเสี่ยง  • มีการประชุมคณะกรรมการบริหารวาระด่วน • ทำงานโดยใช้โครงสร้างการบริหารเดิมที่มีอยู่แล้ว,  มีการใช้ข้อมูลจากผลสำรวจ (เท่าที่มี) มาตัดสินใจจัดการปัญหาของอาจารย์และนักศึกษาที่ได้รับผลกระทบ  \u200b  มิติสิ่งสนับ
PERMIT  90 DAYS REPORT  FORMS   ● TM.7 – Application for Extension of Temporary Stay in the Kingdom  ● TM.8 – Application for Re-entry Permit to Return into the Kingdom  ● TM.30 – Receipt of Notification Form for House-Master, Owner or Possessor of Residence or Hotel Manager Where Alien Has Stayed  ● TM.47 – FORM FOR ALIEN TO NOTIFY OF STAYING LONGER THAN 90 DAYS  ● STM.2 – Acknowledgement of Terms and Conditions for Permit of Temporary Stay in the Kingdom of Thailand  ● The Acknowledgement of Penalties for a Visa Overstay Form  ● Power of Attorney                                   VISA / WORK PERMIT      Guidelines for international students and staff at the Faculty of Medicine, CMU       Visa Extension  The holders of Non-Immigrant Visa are initially granted a period of stay in the Thailand not exceeding 90 days from the arrival date. Those who wish to stay longer than such period must apply for extension of stay at Immigration Office before the expiration date. Students are required to provide the documents to IRU at least 3 weeks prior to their visa expiry date. Otherwise, there will be a penalty if the visa has expired.  Visa Extension documents required:  – A copy of the first page of passport  – All copies of Non-Immigrant “ED” or “B” visa on the passport  – A Copy of Notification Form for House Master of the Residence where Aliens have stayed (TM.30)  – A copy of departure card (TM.6) — (if any)  – A copy of Receipt of notify 90 day — (if any)  – A copy of CMU Transcript or working timetable  – A recent photograph (4 x 6 cm)  The fee for each visa extension is 1,900 Baht paid to Thai Immigration.  In the case of foreigners staying beyond the expiration date of the visa or delaying the visa extension process (Overstay), they must be fined. The minimum charge is 500 Baht per day, reaching a maximum fine of 20,000 Baht (when overstaying 40 or more days) paid to Immigration.  Faculty of Medicine shall not accept any responsibility for students who submit their extension application late.      90-day Reporting  Holders of a Non-Immigrant Visa must report their current address to a Thai immigration office every 90 days. This reporting does not need the documents from IRU and can be done four ways:  – In person at a Thai immigration office  – Through an agent who has the Power of Attorney to report you status  – By mail  – On the website: https://www.immigration.go.th/en  => Online Services  If you are not in Thailand on the date your 90-day reporting is due, you do not need to report your status. Your 90-day reporting will begin again from day 1 on the day you re-enter Thailand.      Re-entry Permit  During your stay, if students plan on leaving and re-entering Thailand whilst on Non-Immigrant Visa, you have to apply for a Re-entry Permit in order to be allowed to leave and re-enter Thailand without  ...
#    'title': 'VISA / WORK PERMIT - International Relations Unit',
#    'url': 'https://w1.med.cmu.ac.th/foreign/en/visa-work-permit/'},
#   {'score': 5.376922076953975,
# ...
#    'title': 'INTERNATIONAL PROGRAM - Department of Biochemistry',
#    'url': 'https://w1.med.cmu.ac.th/biochem/international-program/'},
#   {'score': 5.334186646444087,
#    'text': "This website uses Cookies. Click Accept to agree to our website's cookie use as described in our Privacy Policy . Click Preferences to customize your cookie settings.    Accept    Reject    Preferences                 Browse            Google Cloud      Google Workspace      AppSheet      Looker      Google Cloud Security                                 All community Knowledge base Users              cancel     Turn on suggestions   Auto-suggest helps you quickly narrow down your search results by suggesting possible matches as you type.      Showing results for    Search instead for    Did you mean:         Log in to ask a question               Log in to ask a question              Welcome to the  Google Cloud Communities  Meet industry peers, ask questions, collaborate to find answers, and connect with Googlers who are making the products you use every day.         177K Members    7,243 Online    21.6K Solutions                                Find answers, ask questions, and connect with Google Cloud experts.   Visit the community        Find answers, ask questions, and connect with Google Workspace experts.   Visit the community        The official forum for Q&A about creating applications with AppSheet.   Visit the community        The place for data-driven discussion and all your Looker questions, answers, and excitement.   Visit the community        The place to connect with Chronicle SIEM and SOAR users and security operations pros from around the world.   Visit the community        Share best practices around preparing for certification and network with others on your path.   Visit the community        The independent Google Cloud Community.   Visit the community       A Place to Collaborate With Peers and Product Experts    Trending Google Cloud Product Discussions  Trending Google Workspace for Admins Product Discussions        Make your mark by taking the Cloud Digital Leader beta certification exam [Updated]   By   carrie             ♥️ Arcade February - the quest for swags begin! ♥️   By   Yugali             A Year in Review -- Check out these accomplishments!   By   shaaland             Does it make sense to use Cloud CDN vs Cloud Storage for reducing cost by caching static content?   By   erickeloi             Google Cloud Community Roundup: 2023 Year in Review!   By   Lauren_vdv             🤔 Google Cloud Arcade Mysteries- Who Am I? 🤔   By   Yugali             Better Together- The Story So Far…..   By   Yugali             Introducing Custom Connectors in Application Integration   By   krupan-google                 Join now and collaborate with the community to solve your toughest business challenges.  Sign in to Start a Topic      Articles from Product Experts and Googlers    Google Cloud Community    Analyzing images with Gemini Pro Vision and BigQuery   See how you can set up a process to analyze images in batch using\nBigQuery and the Gemini Pro Vision model.             by   aliciamw      3 Likes  0 Replies  1126 Views       Google Workspace Community    Tips and resources to maximize your productivity with Duet AI in Google Workspace   Here are five top tips and resources to maximize your productivity with\nDuet AI in Google Workspace.             by   rmaupin      5 Likes  1 Replies  599 Views       Architecture Framework Community    Build an end-to-end data to AI solution on Google Cloud with BigQuery and Vertex AI   Learn how to build an end-to-end data to AI solution on Google Cloud\nusing BigQuery and Vertex AI, including a practical example of a\nreal-time fraud detection system and the architecture behind it.             by   Lauren_vdv      7 Likes  0 Replies  21312 Views                            © 2024 Google. All rights reserved.  Privacy Policy  Terms of Service  Community Guidelines",
#    'title': 'Home - Google Cloud Community',
#    'url': 'https://www.googlecloudcommunity.com/'},
#   {'score': 2.83798010711683,
#    'text': 'help_outline Support Sign in home Home workspaces Recommended for Google Workspace arrow_right assistant Editor\'s choice Intelligent apps Work from everywhere Business essentials Apps to discover google Built by Google arrow_right insert_chart_outlined Top charts Most popular Top rated arrow_right category Categories arrow_right Business tools Accounting & finance Administration & management ERP & logistics HR & legal Marketing & analytics Sales & CRM arrow_right Productivity Creative tools Web development Office applications Task management arrow_right Education Academic resources Teacher & admin tools Communication Utilities tenancy Admin managed tune All filters Works with Drive Gmail Calendar Docs Sheets Slides Forms Classroom Chat Meet Price Any Free of charge Paid Rating Any 3.5+ 4.0+ 4.5+ Clear all Done Works with arrow_drop_down Drive Gmail Calendar Docs Sheets Slides Forms Classroom Chat Meet Clear all Done Price arrow_drop_down  check Any check Free of charge check Paid Recommended for Google Workspace info More details about user reviews These apps are sponsored as part of a Google partner program. Learn more open_in_new . View more Yet Another Mail Merge: Mail Merge for Gmail Talarian 4.7 14M+ verified_user This app passed an independent security assessment. Learn\xa0More AODocs AODocs 4.6 7M+ verified_user This app passed an independent security assessment. Learn\xa0More RingCentral for Google Workspace RingCentral 3.8 379K+ verified_user This app passed an independent security assessment. Learn\xa0More Intelligent apps info More details about user reviews These apps are AI-powered apps to help you work smarter and save time. Learn more open_in_new . View more Mergo mail merge Email marketing by Scriptit 4.9 3M+ verified_user This app passed an independent security assessment. Learn\xa0More AI Mail Assistant - ChatGPT™ for Gmail™ Klart AI 4.3 148K+ Automagical TeacherHelper Unicorn Magic 0.0 60K+ Work from everywhere info More details about user reviews These apps help your organization be more productive. Learn more open_in_new . View more Microsoft Teams Meeting Microsoft Corporation 3.4 12M+ Free Invoice for Gmail  - Bookipi Bookipi Team 4.5 106K+ Field Trip Union Code 0.0 13K+ Business essentials info More details about user reviews These apps help increase workflow productivity. Learn more open_in_new . View more Time Tracker TimeNavi 4.3 354K+ BlogIn BlogIn, LLC 5.0 109K+ Castodia Data Connector Castodia, Inc. 4.0 50K+ Apps to discover info More details about user reviews These apps are new and innovative. Learn more open_in_new . View more ClickUp ClickUp 3.2 209K+ Quire Quire team 4.8 130K+ LumApps for Google Chat™ www.lumapps.com 0.0 31K+ verified_user This app passed an independent security assessment. Learn\xa0More Built by Google info More details about user reviews These apps are built by Google. Learn more open_in_new . View more Giphy for Google Chat Google 5.0 748K+ Zendesk® Connector Google 3.9 207K+ PagerDuty for Google Chat Google 5.0 15K+ Most popular info More details about user reviews View more Form Ranger New Visions Cloudlab Form Ranger allows you to populate multiple choice, list, checkbox, and grid options from columns in any Sheet or Doctopus roster. 3.6 49M+ CoRubrics Jaume Feliu Evaluation, co-evaluation and self-evaluation easily with Rubrics 4.4 44M+ TeX equation editor atomurl.net/math You can generate an image of a mathematical formula using the TeX. Paste the TeX equation, QR Code, Barcode to Google documents. 4.3 30M+ Pixabay Free Images Tanya Gupta, learnin60seconds.com Use this add-on to choose from thousands of striking, beautiful images and insert them in your Google Docs document, all without worrying about copyright. Pixabay images are released under Creative Commons CC0 into the public domain. 3.7 29M+ Top rated info More details about user reviews View more Publigo document merge Scriptit Email & print personalized docs and PDFs based on templates + spreadsh ...
#    'title': 'Download Business Apps in Marketplace | Google Workspace',
#    'url': 'https://workspace.google.com/marketplace/'},
#   {'score': 2.767757844216029,
#    'text': "help_outline Support Sign in home Home workspaces Recommended for Google Workspace arrow_right assistant Editor's choice Intelligent apps Work from everywhere Business essentials Apps to discover google Built by Google arrow_right insert_chart_outlined Top charts Most popular Top rated arrow_right category Categories arrow_right Business tools Accounting & finance Administration & management ERP & logistics HR & legal Marketing & analytics Sales & CRM arrow_right Productivity Creative tools Web development Office applications Task management arrow_right Education Academic resources Teacher & admin tools Communication Utilities tenancy Admin managed tune All filters Works with Drive Gmail Calendar Docs Sheets Slides Forms Classroom Chat Meet Price Any Free of charge Paid Rating Any 3.5+ 4.0+ 4.5+ Clear all Done Works with arrow_drop_down Drive Gmail Calendar Docs Sheets Slides Forms Classroom Chat Meet Clear all Done Price arrow_drop_down  check Any check Free of charge check Paid Recommended for Google Workspace info More details about user reviews These apps are sponsored as part of a Google partner program. Learn more open_in_new . View more Yet Another Mail Merge: Mail Merge for Gmail Talarian 4.7 14M+ verified_user This app passed an independent security assessment. Learn\xa0More Copper CRM for Google Sheets™ copper.com 4.5 748K+ verified_user This app passed an independent security assessment. Learn\xa0More LumApps Publish in Google Workspace™ LumApps 4.9 162K+ verified_user This app passed an independent security assessment. Learn\xa0More Intelligent apps info More details about user reviews These apps are AI-powered apps to help you work smarter and save time. Learn more open_in_new . View more GPT for Google Forms™ | Quiz Builder | ChatGPT Lincoln Apps 4.7 424K+ SheetGPT - AI and ChatGPT for Sheets™ SheetGPT 4.5 331K+ Dialpad Add-on Dialpad, Inc 3.7 203K+ verified_user This app passed an independent security assessment. Learn\xa0More Work from everywhere info More details about user reviews These apps help your organization be more productive. Learn more open_in_new . View more PDF Toolbox Digital Inspiration 3.7 206K+ Atlas bot codedoers 0.0 133K+ Field Trip Union Code 0.0 13K+ Business essentials info More details about user reviews These apps help increase workflow productivity. Learn more open_in_new . View more Lucidchart Diagrams for Gmail Lucid Software 4.4 1M+ GMass for Gmail™ GMass, Inc. 4.8 1M+ Aha! Aha! 4.0 315K+ Apps to discover info More details about user reviews These apps are new and innovative. Learn more open_in_new . View more Box Box 4.4 1M+ Figma Figma 2.7 1M+ Chat for Confluence Hakeem Baba 0.0 76K+ Built by Google info More details about user reviews These apps are built by Google. Learn more open_in_new . View more Form Notifications Google 4.1 37M+ Google Analytics google-analytics-add-ons 4.3 16M+ Workday for Google Chat™ Google 1.0 15K+ Most popular info More details about user reviews View more CoRubrics Jaume Feliu Evaluation, co-evaluation and self-evaluation easily with Rubrics 4.4 44M+ Digication www.digication.com Digication is an ePortfolio tool for students to share their work online with their friends, teachers, and potential employers. 3.6 33M+ Timer for Google Forms - Extended Forms ExpressTech Timer for Google Forms. Add a 1-click count down timer for your Google Forms.  Google Classroom integration, auto submit on timer expiry and much more. 4.1 32M+ FormCreator Automagical Apps Quickly create Form, Surveys, Quizzes/Exams and generate multiple versions. 3.5 29M+ Top rated info More details about user reviews View more Mail Merge for Gmail Qualtir Send 2000+ personalized emails / day with Gmail. Track opens & responses. Follow up. 4.8 893K+ Colaboratory Colaboratory team This allows Google Colaboratory to open and create files in Google Drive. It is automatically installed on first use; uninstalling this will not prevent access to Colaboratory. 4.7 56M+ ProWritingAid G ...
#    'title': 'Download Business Apps in Marketplace | Google Workspace',
#    'url': 'https://workspace.google.com/marketplace?hl=en'}],
#  'status': 'success'}

# %% [markdown]
# ## PageRank tutorial (pg 75-81)

# %%
pr.pr_result.sort_values(by='score', ascending=False)
# Out:
#                                                        score
# https://w2.med.cmu.ac.th/rau/                       0.000275
# https://www.med.cmu.ac.th/web/about-medcmu/lead...  0.000195
# https://www.med.cmu.ac.th/web/about-medcmu/fact...  0.000194
# https://w2.med.cmu.ac.th/rau/backend/               0.000159
# https://developers.google.com/youtube               0.000151
# ...                                                      ...
# https://www.med.cmu.ac.th/web/#1637725171497-3f...   0.00011
# https://www.google.org/                              0.00011
# https://www.med.cmu.ac.th/nature/volumes/586         0.00011
# https://www.med.cmu.ac.th/nature/volumes/374         0.00011
# https://www.med.cmu.ac.th/nature/volumes/216         0.00011
#
# [296 rows x 1 columns]
