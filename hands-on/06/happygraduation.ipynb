# %%
from urllib.parse import urlparse, urljoin
from concurrent.futures import ThreadPoolExecutor, wait
import multiprocessing
from queue import Queue, Empty
from pathlib import Path
import os
import pickle
import requests
from bs4 import BeautifulSoup, Comment
import json

# %% [markdown]
# ## Develop a simple multithreaded web crawler (pg 36-41)

# %%
class MultiThreadedCrawler:
    def __init__(self, base_url, depth):
        self.base_url = base_url
        extracted_url = urlparse(self.base_url)
        parent = extracted_url.path[: extracted_url.path.rfind("/") + 1]
        self.root_url = f"{extracted_url.scheme}://{extracted_url.netloc}{parent}"
        self.pool = ThreadPoolExecutor(max_workers=multiprocessing.cpu_count())
        self.to_crawl = Queue()
        self.to_crawl.put({self.base_url: depth})
        self.stored_folder = Path(os.path.abspath("")) / "crawled/"
        self.pickle_name=f"{str(hash(self.root_url))}@{depth}.pickle"
        self.pending_crawl = set()
        self.depth = depth
        print(self.stored_folder)
        if not Path(self.stored_folder).exists():
            Path.mkdir(self.stored_folder)
        if Path(self.stored_folder / self.pickle_name).exists():
            with open(self.stored_folder / self.pickle_name, "rb") as f:
                self.crawled_pages = pickle.load(f)
            print(self.crawled_pages)
        else:
            self.crawled_pages = set()

    def extract_page(self, obj):
        if obj.result():
            result, url, depth = obj.result()
            self.pending_crawl.remove(url)
            if result and result.status_code == 200:
                self.crawled_pages.add(url)
                url_lists = self.parse_links(result.text, depth)
                self.parse_contents(url, result.text, url_lists)

    def get_page(self, url, depth):
        try:
            res = requests.get(url, timeout=(3, 30))
            return res, url, depth
        except requests.RequestException as e:
            print(e)
            return

    def parse_links(self, html, depth):
        soup = BeautifulSoup(html, "html.parser")
        links = soup.find_all("a", href=True)
        url_lists = []
        for link in links:
            url = link["href"]
            url = urljoin(self.root_url, url)
            if url not in self.crawled_pages.union(self.pending_crawl) and depth >= 0 and r"." not in url.split(r"/")[-1]:
                print("Adding@{}: {}".format(depth, url))
                self.to_crawl.put({url: depth})
            url_lists.append(url)
        return url_lists

    def parse_contents(self, url, html, url_lists):
        def tag_visible(element):
            if element.parent.name in [
                "style",
                "script",
                "head",
                "title",
                "meta",
                "[document]",
            ]:
                return False
            if isinstance(element, Comment):
                return False
            return True

        try:
            soup = BeautifulSoup(html, "html.parser")
            texts = soup.findAll(string=True)
            visible_texts = filter(tag_visible, texts)
            title = ""
            if soup.find("title"):
                title = soup.find("title").string.strip()
            text = " ".join(t.strip() for t in visible_texts).strip()
            with open(
                self.stored_folder / (str(hash(url)) + ".json"), "w", encoding="utf-8"
            ) as f:
                json.dump(
                    {"url": url, "title": title, "text": text, "url_lists": url_lists},
                    f,
                    ensure_ascii=False,
                    indent=4,
                )
        except:
            pass

    def run_scraper(self):
        while True:
            try:
                target = self.to_crawl.get(timeout=10)
                url, depth = [(k, target[k]) for k in target][0]
                if (url not in self.crawled_pages.union(self.pending_crawl) and depth >= 0) or depth == self.depth:
                    self.pending_crawl.add(url)
                    job = self.pool.submit(self.get_page, url, depth - 1)
                    job.add_done_callback(self.extract_page)
            except Empty:
                self.pool.shutdown(wait=True)
                with open(self.stored_folder / self.pickle_name, "wb") as f:
                    pickle.dump(self.crawled_pages, f, pickle.HIGHEST_PROTOCOL)
                with open(self.stored_folder / self.pickle_name, "rb") as f:
                    print(pickle.load(f))
                break
            except Exception as e:
                print(e)
                continue

# %%
s = MultiThreadedCrawler("https://camt.cmu.ac.th/index.php/en/", 3)
s.run_scraper()
# Out:
# /home/mansmooth/ir-py/hands-on/06/crawled
# Adding@2: https://service.camt.cmu.ac.th/studentForm/
# Adding@2: https://service.camt.cmu.ac.th/complaint/
# Adding@2: https://camt.cmu.ac.th/index.php/th/
# Adding@2: https://camt.cmu.ac.th/index.php/en/component/users/?view=remind&Itemid=101
# Adding@2: https://camt.cmu.ac.th/index.php/en/component/users/?view=reset&Itemid=101
# Adding@2: https://ditc.camt.cmu.ac.th/
# Adding@2: http://meetingroom.camt.cmu.ac.th/
# Adding@2: https://smartoffice.camt.cmu.ac.th/v1r
# Adding@2: https://service.camt.cmu.ac.th/onestop
# Adding@2: https://service.camt.cmu.ac.th/studentForm/
# Adding@2: https://lib.camt.cmu.ac.th/
# Adding@2: https://cmu.to/CAMT-SLRF
# Adding@2: https://pandit.camt.cmu.ac.th/
# Adding@2: https://service.camt.cmu.ac.th/iso/
# Adding@2: https://service.camt.cmu.ac.th/gifted
# Adding@2: https://web.microsoftstream.com/channel/a9f73640-9088-4ee8-b1eb-098e15ca8a68
# Adding@2: https://cmu.to/camt-files
# Adding@2: https://camt.cmu.ac.th/
# Adding@2: https://camt.cmu.ac.th/
# Adding@2: https://www.cmu.ac.th/th/privacy
# Adding@1: https://camt.cmu.ac.th/index.php/en/?p=calendar
# Adding@1: https://camt.cmu.ac.th/index.php/en/?p=calendar
# Adding@1: https://camt.cmu.ac.th/index.php/en/?p=meeting_room
# Adding@1: https://camt.cmu.ac.th/index.php/en/?p=service_catalog
# Adding@1: https://camt.cmu.ac.th/index.php/en/?p=profile_catalog
# Adding@1: https://camt.cmu.ac.th/index.php/en/?p=download_documents
# Adding@1: https://camt.cmu.ac.th/index.php/en/?p=download_documents_list&key=5c5e5b8cb9463a6938cd508e6eef950f
# Adding@1: https://camt.cmu.ac.th/index.php/en/?p=download_documents_list&key=97b47403e6d26bd50503db2ff6e3785a
# Adding@1: https://camt.cmu.ac.th/index.php/en/?p=download_documents_list&key=4b17c2542132f07a81da34bcda676ca9
# Adding@1: https://camt.cmu.ac.th/index.php/en/?p=download_documents_list&key=e69c58bb2e46609c327f6dcb21912ed9
# Adding@1: https://camt.cmu.ac.th/index.php/en/?p=contact
# Adding@1: https://camt.cmu.ac.th/index.php/en/?p=&lang=th
# Adding@1: https://camt.cmu.ac.th/index.php/en/?p=&lang=en
# Adding@1: https://camt.cmu.ac.th/index.php/en/admin/
# Adding@1: https://camt.cmu.ac.th/index.php/en/#carousel-example-generic
# Adding@1: https://camt.cmu.ac.th/index.php/en/#carousel-example-generic
# Adding@1: https://camt.cmu.ac.th/index.php/en/?p=about&key=cf5a7dc31ef4047ebb200619653817e0
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# Adding@0: https://service.camt.cmu.ac.th/iso/home/activities/2/
# Adding@0: https://service.camt.cmu.ac.th/iso/home/activities/2/
# Adding@0: https://service.camt.cmu.ac.th/iso/home/activities/3/
# Adding@0: https://service.camt.cmu.ac.th/iso/home/activities/3/
# Adding@0: https://service.camt.cmu.ac.th/iso/home/activities/4/
# Adding@0: https://service.camt.cmu.ac.th/iso/home/activities/4/
# Adding@0: https://camt.cmu.ac.th/index.php/en/#content
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/undergraduate/?T=U
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/graduate/?T=U
# Adding@0: https://regist.reg.cmu.ac.th/
# Adding@0: https://studentplus.reg.cmu.ac.th/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/faculty/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/department/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/instructor/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/insidecmu/
# Adding@0: https://admission.reg.cmu.ac.th/
# Adding@0: http://finance.oop.cmu.ac.th/?q=th/tuition_fee_announcement
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/reg_procure/
# Adding@0: https://www.reg.cmu.ac.th/webreg/reg-job/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/links/
# Adding@0: https://www1.reg.cmu.ac.th/degreeverification/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/regabout/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/regabout/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/structure/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/vision/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/executive/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/regstaff1/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/regstaff2/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/regstaff3/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/regstaff4/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/regstaff5/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/regstaff6/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/contact/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/reg-newsletter/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/clip-suggestion/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/regmis
# Adding@0: https://www.reg.cmu.ac.th/webreg/en/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/calendar/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/eventics/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/reg-handbook/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/reg-form/
# Adding@0: https://www3.reg.cmu.ac.th/mis-reg/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/reg-oit-66/
# Adding@0: https://www3.reg.cmu.ac.th/stdinfo/
# Adding@0: https://www1.reg.cmu.ac.th/reg-transfer/
# Adding@0: https://www1.reg.cmu.ac.th/reg-grad/
# Adding@0: https://www.reg.cmu.ac.th/web/reg-diploma/
# Adding@0: https://www1.reg.cmu.ac.th/reg-document/
# Adding@0: https://www.facebook.com/RegCMU
# Adding@0: https://docs.google.com/forms/d/e/1FAIpQLSc9IDnD2bHxOpFQ_1iQ0bbulwCVwVnkuQGXtmu1SlOquRbTkA/viewform
# Adding@0: https://www.facebook.com/RegCMU
# Adding@0: https://twitter.com/RegCmu
# Adding@0: https://www.youtube.com/user/RegCMU
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/privacy/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/counterservice/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/regannual/
# Adding@0: https://www3.reg.cmu.ac.th/goodpractice/
# Adding@0: https://www1.reg.cmu.ac.th/KMs/
# Adding@0: https://stats.uptimerobot.com/k8BGXFORO
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/links/
# Adding@0: https://www.cmu.ac.th/
# Adding@0: https://itsc.cmu.ac.th/
# Adding@0: http://cmuir.cmu.ac.th/
# Adding@0: https://www.reg.cmu.ac.th/webreg/th/privacy/
# Adding@0: https://m.wikihow.com/Disable-Cookies
# Adding@0: https://th.m.wikihow.com/%E0%B8%A2%E0%B8%81%E0%B9%80%E0%B8%A5%E0%B8%B4%E0%B8%81%E0%B8%81%E0%B8%B2%E0%B8%A3%E0%B9%83%E0%B8%8A%E0%B9%89%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%84%E0%B8%B8%E0%B8%81%E0%B8%81%E0%B8%B5%E0%B9%89
# Adding@0: https://camt.cmu.ac.th/contact
# Adding@0: https://camt.cmu.ac.th/contact
# Adding@0: https://camt.cmu.ac.th/contact
# Adding@0: https://camt.cmu.ac.th/contact
# Adding@0: https://camt.cmu.ac.th/contact
# Adding@0: https://camt.cmu.ac.th/contact
# Adding@0: https://camt.cmu.ac.th/contact
# Adding@0: https://www.designbootstrap.com/web-design/cave-creek
# Adding@0: http://www.designbootstrap.com/web-design/paradise-valley
# Adding@0: https://www.designbootstrap.com/web-design/athens-ga
# Adding@0: https://camt.cmu.ac.th/contact
# Adding@0: https://camt.cmu.ac.th/contact
# Adding@0: https://camt.cmu.ac.th/forms/about/
# Adding@0: https://docs.google.com/forms/u/0/?tgif=d&ec=asw-forms-globalnav-signin
# Adding@0: https://docs.google.com/forms/u/0/?tgif=d&ec=asw-forms-globalnav-goto
# Adding@0: https://workspace.google.com/intl/en/features/?utm_source=formsforwork&utm_medium=et&utm_content=tryformsforwork&utm_campaign=globalnav
# Adding@0: https://camt.cmu.ac.th/forms/about/
# Adding@0: https://camt.cmu.ac.th/index.php/en/#overview
# Adding@0: https://camt.cmu.ac.th/index.php/en/#features
# Adding@0: https://camt.cmu.ac.th/index.php/en/#security
# Adding@0: https://camt.cmu.ac.th/index.php/en/#pricing
# Adding@0: javascript:
# Adding@0: https://www.google.com/drive/?hl=en
# Adding@0: https://www.google.com/gmail/about/?hl=en
# Adding@0: https://apps.google.com/meet/?hl=en
# Adding@0: https://workspace.google.com/intl/en/products/calendar/?utm_source=formsforwork&utm_medium=et&utm_content=calendar&utm_campaign=globalnav
# Adding@0: https://camt.cmu.ac.th/docs/about/
# Adding@0: https://camt.cmu.ac.th/sheets/about/
# Adding@0: https://camt.cmu.ac.th/slides/about/
# Adding@0: https://camt.cmu.ac.th/forms/about/
# Adding@0: https://www.google.com/drive/?hl=en
# Adding@0: https://www.google.com/gmail/about/?hl=en
# Adding@0: https://apps.google.com/meet/?hl=en
# Adding@0: https://workspace.google.com/intl/en/products/calendar/?utm_source=formsforwork&utm_medium=et&utm_content=calendar&utm_campaign=globalnav
# Adding@0: https://camt.cmu.ac.th/docs/about/
# Adding@0: https://camt.cmu.ac.th/sheets/about/
# Adding@0: https://camt.cmu.ac.th/slides/about/
# Adding@0: https://camt.cmu.ac.th/forms/about/
# Adding@0: https://workspace.google.com/intl/en/?utm_source=formsforwork&utm_medium=et&utm_content=learnmore&utm_campaign=globalnav
# Adding@0: https://docs.google.com/forms/u/0/?tgif=d&ec=asw-forms-globalnav-signin
# Adding@0: https://docs.google.com/forms/u/0/?tgif=d&ec=asw-forms-globalnav-goto
# Adding@0: https://workspace.google.com/intl/en/features/?utm_source=formsforwork&utm_medium=et&utm_content=tryformsforwork&utm_campaign=globalnav
# Adding@0: https://workspace.google.com/intl/en/features/?utm_source=formsforwork&utm_medium=et&utm_content=tryformsforwork&utm_campaign=hero
# Adding@0: https://docs.google.com/forms/u/0/?tgif=d&ec=asw-forms-hero-goto
l=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-useful-ads
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-people-online
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-unique-id
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-device
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-personal-info
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-personal-info
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-phone-number
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-payment-info
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-devices
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-unique-id
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-ip
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-referrer-url
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-android-device
# Adding@0: https://support.google.com/android/answer/9021432?hl=en_US
# Adding@0: https://support.google.com/accounts/answer/6078260?hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-content-views
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-voice-audio-information
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-chrome-sync
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-calls-messages
# Adding@0: https://myaccount.google.com/?utm_source=pp&hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-sensor-data
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-ip
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-activity-on-services
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-places-you-label
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-near-device
# Adding@0: https://support.google.com/accounts?p=privpol_location&hl=en_US
# Adding@0: https://support.google.com/accounts?p=privpol_lochistory&hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/technologies/location-data?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-sources
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-against-abuse
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-ad-services
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-cookies
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-pixel
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-browser-storage
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-application-data-cache
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-server-logs
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-deliver-services
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-ensure-working
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-make-improvements
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-customized-search
# Adding@0: https://myaccount.google.com/security-checkup?utm_source=pp&hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-personalized-ads
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-sensitive-categories
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-link-info
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-safety-reliability
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-the-public
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-detect-abuse
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-algorithm
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-combine-info
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-other-sites
# Adding@0: https://myaccount.google.com/privacycheckup?utm_source=pp&utm_medium=Promo-in-product&utm_campaign=pp_body&hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/technologies/product-privacy?gl=TH&hl=en-US
# Adding@0: https://myaccount.google.com/privacycheckup?utm_source=pp&utm_medium=Promo-in-product&utm_campaign=pp_body&hl=en_US
# Adding@0: https://myaccount.google.com/?hl=en_US
# Adding@0: https://support.google.com/websearch/answer/54068?hl=en_US#zippy=%2Cinfo-about-your-browsing-and-other-activity-on-sites-apps-and-devices-that-use-google-services
# Adding@0: https://myaccount.google.com/activitycontrols?utm_source=pp&hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-partner
# Adding@0: https://myaccount.google.com/profile?utm_source=pp&hl=en_US
# Adding@0: https://myaccount.google.com/shared-endorsements?utm_source=pp&hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/technologies/partner-sites?gl=TH&hl=en-US&hl=en_US
# Adding@0: https://myactivity.google.com/myactivity?utm_source=pp&hl=en_US
# Adding@0: https://myaccount.google.com/dashboard?utm_source=pp&hl=en_US
# Adding@0: https://myaccount.google.com/personal-info?utm_source=pp&hl=en_US
# Adding@0: https://www.google.com/history/optout?utm_source=pp&hl=en_US
# Adding@0: https://www.youtube.com/feed/history/search_history?utm_source=pp&hl=en_US
# Adding@0: https://www.youtube.com/feed/history?utm_source=pp&hl=en_US
# Adding@0: https://takeout.google.com/?utm_source=pp&hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-delete-specific
# Adding@0: https://myactivity.google.com/?utm_source=pp&hl=en_US
# Adding@0: https://myaccount.google.com/deleteservices?utm_source=pp&hl=en_US
# Adding@0: https://myaccount.google.com/deleteaccount?utm_source=pp&hl=en_US
# Adding@0: https://myaccount.google.com/delete-services-or-account?utm_source=pp&hl=en_US
# Adding@0: https://myaccount.google.com/inactive?utm_source=pp&hl=en_US
# Adding@0: https://support.google.com/legal/answer/3110420?visit_id=637939486089565735-343938859&hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-cookies
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-rely-on-cookies
# Adding@0: https://support.google.com/websearch?p=privpol_locserp&hl=en_US
# Adding@0: https://support.google.com/accounts?p=privpol_endorse&hl=en_US
# Adding@0: https://support.google.com/googlehome?p=privpol_homedata&hl=en_US
# Adding@0: https://myaccount.google.com/permissions?hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-sensitive-info
# Adding@0: https://support.google.com/a?p=privpol_admin&hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-affiliates
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-legal
# Adding@0: https://transparencyreport.google.com/user-data/overview?hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-our-users
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-info
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-trends
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-specific-partners
# Adding@0: https://safebrowsing.google.com/?utm_source=pp&hl=en_US
# Adding@0: https://www.google.com/landing/2step/?utm_source=pp&hl=en_US
# Adding@0: https://takeout.google.com/?utm_source=pp&hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-delete-specific
# Adding@0: https://myactivity.google.com/?utm_source=pp&hl=en_US
# Adding@0: https://myaccount.google.com/deleteservices?utm_source=pp&hl=en_US
# Adding@0: https://myaccount.google.com/deleteaccount?utm_source=pp&hl=en_US
# Adding@0: https://myaccount.google.com/delete-services-or-account?utm_source=pp&hl=en_US
# Adding@0: https://myaccount.google.com/personal-info?hl=en_US
# Adding@0: https://support.google.com/photos/answer/6128858?hl=en_US
# Adding@0: https://support.google.com/docs/answer/6023494?hl=en_US
# Adding@0: https://myactivity.google.com/myactivity?hl=en_US
# Adding@0: https://support.google.com/accounts/answer/465?authuser=0&hl=en_US#auto-delete
# Adding@0: https://camt.cmu.ac.th/index.php/en/technologies/ads?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/technologies/retention?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-servers
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy/frameworks?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US#footnote-affiliates
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy/archive?gl=TH&hl=en-US
# Adding@0: https://fi.google.com/about/tos/#project-fi-privacy-notice
# Adding@0: https://ssl.gstatic.com/seekh/intl/en/privacy
# Adding@0: https://kids.youtube.com/privacynotice
# Adding@0: https://families.google.com/familylink/privacy/child-policy/
# Adding@0: https://families.google.com/familylink/privacy/child-disclosure/?hl=en_US
# Adding@0: https://assistant.google.com/privacy-notice-childrens-features/?hl=en_US
# Adding@0: https://cloud.google.com/terms/cloud-privacy-notice?hl=en_US
# Adding@0: https://myaccount.google.com/?hl=en_US
# Adding@0: https://myaccount.google.com/privacycheckup?utm_source=pp&utm_medium=Promo-in-product&utm_campaign=pp_body&hl=en_US
# Adding@0: https://www.google.com/intl/en/safetycenter/
# Adding@0: https://www.google.com/policies/privacy/teens/?hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/technologies?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/technologies/cookies?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/technologies/ads?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/technologies/partner-sites?gl=TH&hl=en-US
# Adding@0: https://privacy.google.com/businesses/affiliates?hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/technologies/cookies?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/technologies/partner-sites?gl=TH&hl=en-US
# Adding@0: https://myaccount.google.com/?hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/technologies/location-data?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/technologies/cookies?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/technologies/ads?gl=TH&hl=en-US
# Adding@0: https://myactivity.google.com/activitycontrols?hl=en_US
# Adding@0: https://support.google.com/accounts?p=privpol_whyad&hl=en_US
# Adding@0: https://support.google.com/accounts?p=privpol_whyad&hl=en_US
# Adding@0: https://support.google.com/android/answer/10546414?hl=en_US
# Adding@0: https://support.google.com/websearch?p=privpol_privresults&hl=en_US
# Adding@0: https://support.google.com/accounts?p=autocontacts&hl=en_US
# Adding@0: https://support.google.com/websearch?p=privpol_feed&hl=en_US
# Adding@0: https://support.google.com/googlehome?p=privpol_actions&hl=en_US
# Adding@0: https://support.google.com/websearch?p=privpol_searchactivity&hl=en_US
# Adding@0: https://support.google.com/websearch?p=privpol_incognito&hl=en_US
# Adding@0: https://www.google.com/history/optout?utm_source=pp&hl=en_US
# Adding@0: https://support.google.com/photos?p=privpol_manage&hl=en_US
# Adding@0: https://protectingchildren.google/?hl=en_US
# Adding@0: https://support.google.com/accounts?p=privpol_androidloc&hl=en_US
# Adding@0: https://transparencyreport.google.com/user-data/overview?hl=en_US
# Adding@0: https://support.google.com/analytics?p=privpol_data&hl=en_US
# Adding@0: https://support.google.com/legal/answer/12158374?hl=en_US
# Adding@0: https://support.google.com/accounts?p=privpol_controlads&hl=en_US
# Adding@0: https://support.google.com/accounts?p=privpol_agereq&hl=en_US
# Adding@0: https://support.google.com/accounts?p=privpol_whyad&hl=en_US
# Adding@0: https://support.google.com/accounts?p=privpol_phone&hl=en_US
# Adding@0: https://myaccount.google.com/personal-info?hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/technologies/cookies?gl=TH&hl=en-US#types-of-cookies
# Adding@0: https://support.google.com/mail?p=privpol_signinactivity&hl=en_US
# Adding@0: https://support.google.com/adwordspolicy?p=privpol_p13nad&hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/technologies/location-data?gl=TH&hl=en-US
# Adding@0: https://www.google.com/about/datacenters/inside/locations?hl=en_US
# Adding@0: https://support.google.com/trends?p=privpol_about&hl=en_US
# Adding@0: https://support.google.com/blogger?p=privpol_blog&hl=en_US
# Adding@0: https://support.google.com/sites?p=privpol_delete&hl=en_US
# Adding@0: https://support.google.com/googleplay?p=privpol_review&hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy/google-partners?gl=TH&hl=en-US
# Adding@0: https://support.google.com/chrome?p=privpol_chrsync&hl=en_US
# Adding@0: https://support.google.com/legal/answer/3110420?visit_id=637939486089565735-343938859&hl=en_US
# Adding@0: https://support.google.com/websearch/answer/6030020?hl=en_US#zippy=%2Chow-audio-recordings-are-saved
# Adding@0: https://myaccount.google.com/?hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/technologies/partner-sites?gl=TH&hl=en-US
# Adding@0: https://www.google.com/
# Adding@0: https://camt.cmu.ac.th/index.php/en/privacy?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US
# Adding@0: https://transparency.google/?hl=en_US
# Adding@0: https://accounts.google.com/ServiceLogin?passive=1209600&continue=https://policies.google.com/terms?gl%3DTH%26hl%3Den-US&followup=https://policies.google.com/terms?gl%3DTH%26hl%3Den-US&hl=en-US&ec=GAZAoQQ
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms/archive?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms/definitions?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms/service-specific?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms/information-requests?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#toc-intro
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#toc-relationship
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#toc-using
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#toc-content
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#toc-software
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#toc-problems
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#toc-about
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms/archive?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms/definitions?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms/service-specific?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms/information-requests?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms/archive?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#footnote-country-version
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#footnote-services
# Adding@0: https://about.google/intl/en_TH/how-our-business-works
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#toc-what-you-expect
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#toc-what-we-expect
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#toc-content
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#toc-problems
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#footnote-services
# Adding@0: https://support.google.com/accounts/answer/1350409?hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#footnote-services
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms/service-specific?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#toc-intro
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#toc-relationship
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#toc-using
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#toc-content
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#toc-software
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#toc-problems
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#toc-about
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#footnote-services
# Adding@0: https://about.google/intl/en_TH/how-our-business-works
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#footnote-affiliates
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#footnote-your-content
# Adding@0: https://takeout.google.com/settings/takeout?hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#footnote-services
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms/service-specific?gl=TH&hl=en-US
# Adding@0: https://support.google.com/legal/topic/4558877?hl=en_US
# Adding@0: https://camt.cmu.ac.th/?gl=TH&hl=en-US
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#footnote-intellectual-property-rights
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms/service-specific?gl=TH&hl=en-US
# Adding@0: https://support.google.com/groups/answer/81275?hl=en_US
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#taking-action
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#footnote-your-content
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#footnote-your-content
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#footnote-intellectual-property-rights
# Adding@0: https://camt.cmu.ac.th/index.php/en/terms?gl=TH&hl=en-US#footnote
# Adding@0: https://camt.cmu.ac.th/accounts/topic/2400093?hl=en&ref_topic=3382297
# Adding@0: https://camt.cmu.ac.th/accounts/answer/9267052?hl=en&ref_topic=3382297
# Adding@0: https://camt.cmu.ac.th/accounts/answer/32047?hl=en&ref_topic=3382297
# Adding@0: https://camt.cmu.ac.th/accounts/answer/1350409?hl=en&ref_topic=7189311
# Adding@0: https://camt.cmu.ac.th/accounts/topic/7189242?hl=en&ref_topic=7189311
# Adding@0: https://camt.cmu.ac.th/accounts/answer/2736362?hl=en&ref_topic=7189311
# Adding@0: https://camt.cmu.ac.th/accounts/topic/14202891?hl=en&ref_topic=7189311
# Adding@0: https://camt.cmu.ac.th/accounts/answer/463?hl=en&ref_topic=7189311
# Adding@0: https://camt.cmu.ac.th/accounts/answer/12418290?hl=en&ref_topic=7189311
# Adding@0: https://camt.cmu.ac.th/accounts/community?hl=en
# Adding@0: https://www.google.com/landing/2step
# Adding@0: https://safety.google/security-privacy/
# HTTPSConnectionPool(host='service.camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='www.cmu.ac.th', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# No connection adapters were found for 'javascript:'
# No connection adapters were found for 'about:invalid#zjslayoutz'
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# HTTPSConnectionPool(host='camt.cmu.ac.th', port=443): Read timed out. (read timeout=3)
# {'https://camt.cmu.ac.th/index.php/en/?p=service_catalog', 'https://workspace.google.com/intl/en/products/keep/?utm_source=formsforwork&utm_medium=et&utm_content=keep&utm_campaign=body', 'https://camt.cmu.ac.th/index.php/en/#messages', 'https://support.google.com/accounts/answer/6078260?hl=en_US', 'https://support.google.com/chrome?p=privpol_chrsync&hl=en_US', 'https://docs.google.com/forms/d/e/1FAIpQLSc9IDnD2bHxOpFQ_1iQ0bbulwCVwVnkuQGXtmu1SlOquRbTkA/viewform', 'http://finance.oop.cmu.ac.th/?q=th/tuition_fee_announcement', 'https://camt.cmu.ac.th/index.php/en/?p=about&key=b3b17c77d5456ce71ee0e53625d29801', 'https://support.google.com/accounts?p=autocontacts&hl=en_US', 'https://support.google.com/accounts?p=privpol_androidloc&hl=en_US', 'https://www.reg.cmu.ac.th/webreg/th/undergraduate/?T=U', 'https://camt.cmu.ac.th/', 'https://support.google.com/accounts?p=privpol_endorse&hl=en_US', 'https://camt.cmu.ac.th/index.php/en/?p=profile_catalog', 'https://camt.cmu.ac.th/index.php/en/#overview', 'https://support.google.com/blogger?p=privpol_blog&hl=en_US', 'https://smartoffice.camt.cmu.ac.th/v1r', 'https://myaccount.google.com/profile?utm_source=pp&hl=en_US', 'https://www.reg.cmu.ac.th/webreg/th/links/', 'https://www.reg.cmu.ac.th/webreg/th/regabout/', 'https://myaccount.google.com/dashboard?utm_source=pp&hl=en_US', 'https://camt.cmu.ac.th/index.php/en/#profile', 'https://accounts.google.com/ServiceLogin?hl=en&passive=true&continue=http://support.google.com/accounts/answer/2917834%3Fvisit_id%3D638427241119215973-3911299457%26p%3Dsignin_privatebrowsing%26hl%3Den%26rd%3D1&ec=GAZAdQ', 'https://www.reg.cmu.ac.th/webreg/th/executive/', 'https://support.google.com/accounts?hl=en-US&p=account_iph', 'https://camt.cmu.ac.th/index.php/en/?p=contact', 'https://support.google.com/accounts/answer/27441?hl=en_US', 'https://groups.google.com/group/GoogleDocs', 'https://www.google.com/history/optout?utm_source=pp&hl=en_US', 'https://camt.cmu.ac.th/index.php/en/?p=about&key=cf5a7dc31ef4047ebb200619653817e0', 'https://regist.reg.cmu.ac.th/', 'https://support.google.com/photos/answer/6128858?hl=en_US', 'https://families.google.com/familylink/privacy/child-disclosure/?hl=en_US', 'https://lib.camt.cmu.ac.th/', 'https://www.reg.cmu.ac.th/webreg/th/reg-handbook/', 'https://www.designbootstrap.com/web-design/cave-creek', 'https://privacy.google.com/businesses/affiliates?hl=en_US', 'https://support.google.com/websearch?p=privpol_feed&hl=en_US', 'https://ssl.gstatic.com/seekh/intl/en/privacy', 'https://workspace.google.com/getgws/chooseemail?utm_source=formsforwork&utm_medium=et&utm_content=forworkormybusiness&utm_campaign=hero&hl=en', 'https://support.google.com/groups/answer/81275?hl=en_US', 'https://pandit.camt.cmu.ac.th/home/lecturer', 'https://camt.cmu.ac.th/index.php/en/#home', 'https://support.google.com/adwordspolicy?p=privpol_p13nad&hl=en_US', 'https://www.reg.cmu.ac.th/webreg/th/regstaff4/', 'https://www1.reg.cmu.ac.th/reg-document/', 'https://support.google.com/a?p=privpol_admin&hl=en_US', 'https://workspace.google.com/intl/en/products/calendar/?utm_source=formsforwork&utm_medium=et&utm_content=calendar&utm_campaign=body', 'https://support.google.com/legal/answer/12158374?hl=en_US', 'https://www.reg.cmu.ac.th/webreg/th/privacy/', 'https://www3.reg.cmu.ac.th/goodpractice/', 'https://www.google.com/forms/about/?utm_source=product&utm_medium=forms_logo&utm_campaign=forms', 'https://about.google/products/', 'https://service.camt.cmu.ac.th/gifted/gifted/index', 'https://myaccount.google.com/activitycontrols', 'https://www.google.co.th/intl/en/about/products', 'https://transparency.google/?hl=en_US', 'https://www.facebook.com/RegCMU', 'https://support.google.com/accounts?p=privpol_phone&hl=en_US', 'https://support.google.com/analytics?p=privpol_data&hl=en_US', 'https://myaccount.google.com/deleteservices?utm_source=pp&hl=en_US', 'https://camt.cmu.ac.th/index.php/en/component/users/?view=reset&Itemid=101', 'https://cloud.google.com/terms/cloud-privacy-not ...

# %% [markdown]
# ## Develop a simple web indexer (pg 43)

# %%
import pandas as pd
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy import sparse
import numpy as np
import re
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %%
class BM25(object):
    def __init__(self, fitted_vectorizer: TfidfVectorizer, b=0.75, k1=1.6):
        self.fitted_vectorizer = fitted_vectorizer
        self.b = b
        self.k1 = k1

    def fit(self, X):
        """Fit IDF to documents X"""
        self.y = super(TfidfVectorizer, self.fitted_vectorizer).transform(X)
        self.avdl = self.y.sum(1).mean()

    def transform(self, q):
        """Calculate BM25 between query q and documents X"""
        b, k1, avdl = self.b, self.k1, self.avdl

        # apply CountVectorizer
        len_y = self.y.sum(1).A1
        (q,) = super(TfidfVectorizer, self.fitted_vectorizer).transform(q)
        assert sparse.isspmatrix_csr(q)

        # convert to csc for better column slicing
        y = self.y.tocsc()[:, q.indices]
        denom = y + (k1 * (1 - b + b * len_y / avdl))[:, None]
        idf = self.fitted_vectorizer._tfidf.idf_[None, q.indices] - 1.0
        numer = y.multiply(np.broadcast_to(idf, y.shape)) * (k1 + 1)
        return (numer / denom).sum(1).A1

# %%
def custom_preprocessor(s: str):
    lemmatizer = WordNetLemmatizer()
    s = re.sub(r"[^A-Za-z]", " ", s)
    s = re.sub(r"\s+", " ", s)
    s = re.sub(" +", " ", s)
    s = s.lower()
    s = word_tokenize(s)
    s = set(s).difference(set(stopwords.words("english")))
    s = [word for word in s if len(word) > 2]
    s = [lemmatizer.lemmatize(w) for w in s]
    s = " ".join(s)
    return s

# %%
class WebIndexer:
    def __init__(self):
        self.crawled_folder = Path(os.path.abspath('')) / 'crawled/'
        self.stored_file = 'indexer/manual_indexer.pickle'
        if not Path(self.stored_file).parent.exists():
            Path.mkdir(Path(self.stored_file).parent)
        if os.path.isfile(self.stored_file):
            with open(self.stored_file, 'rb') as f:
                cached_dict = pickle.load(f)
            self.__dict__.update(cached_dict)
        else:
            self.run_indexer()
    def run_indexer(self):
        documents = []
        for file in os.listdir(self.crawled_folder):
            if file.endswith(".json"):
                j = json.load(open(os.path.join(self.crawled_folder, file)))
                documents.append(j)
        self.documents = pd.DataFrame.from_dict(documents)
        tfidf_vectorizor = TfidfVectorizer(preprocessor=custom_preprocessor, stop_words=stopwords.words('english'))
        tfidf_vectorizor.fit(self.documents.apply(lambda s: ' '.join(s[['title', 'text']]), axis=1))
        self.bm25 = BM25(tfidf_vectorizor)
        self.bm25.fit(self.documents.apply(lambda s: ' '.join(s[['title', 'text']]), axis=1))
        with open(self.stored_file, 'wb') as f:
            pickle.dump(self.__dict__, f)
    def search(self, query):
        scores = self.bm25.transform([query])
        df = pd.DataFrame(scores, columns=["score"])
        return self.documents.join(df)

# %% [markdown]
# ## Quick workout #1: Search using a query ‘school’ with BM25. (pg 44)

# %%
wi = WebIndexer()
wi.search("School").sort_values("score", ascending=False).head(20)
# Out:
#                                                    url  \
# 214              https://service.camt.cmu.ac.th/gifted
# 175                         https://w3.grad.cmu.ac.th/
# 26                         https://www.grad.cmu.ac.th/
# 133  https://service.camt.cmu.ac.th/gifted/gifted/i...
# 25             https://pandit.camt.cmu.ac.th/home/rule
# 171                            http://cmuir.cmu.ac.th/
# 152  https://support.google.com/a?p=privpol_admin&h...
# 64   https://support.google.com/groups/answer/81275...
# 71   https://support.google.com/googleplay?p=privpo...
# 285                        https://www.mids.cmu.ac.th/
# 236  https://support.google.com/docs/answer/6023494...
# 153                    https://support.google.com/docs
# 8    https://support.google.com/mail?p=privpol_sign...
# 290  https://support.microsoft.com/en-us/help/40262...
# 253  https://support.google.com/accounts?p=privpol_...
# 283  https://support.google.com/legal/answer/121583...
# 130  https://support.google.com/accounts?p=privpol_...
# 4    https://support.google.com/websearch/answer/60...
# 254                https://www.google.com/accounts/TOS
# 30             https://policies.google.com/terms?hl=en
#
#                                                  title  \
# 214                                   Gift School 2023
# 175             Graduate School, Chiang Mai University
# 26              Graduate School, Chiang Mai University
# 133                                   Gift School 2566
# 25        CAMT : College of Arts, Media and Technology
# 171                  CMU Intellectual Repository: Home
# 152  Who is my administrator? - Google Workspace Ad...
# 64    Report abuse or legal issue - Google Groups Help
# 71   How to rate & review apps in the Google Play S...
# 285  MIdS : (M)ultidisciplinary and (I)nter(d)iscip...
# 236  Delete a document, spreadsheet, or presentatio...
# 153                           Google Docs Editors Help
# 8                   Last account activity - Gmail Help
# 290  Browse InPrivate in Microsoft Edge - Microsoft...
# 253  Update your account to meet age requirements -...
# 283                           About Lumen - Legal Help
# 130  Manage your Location History - Google Account ...
# 4    Manage audio recordings in your Web & App Acti...
# 254  Google Terms of Service – Privacy & Terms – Go...
# 30   Google Terms of Service – Privacy & Terms – Go...
#
#                                                   text  \
# 214  << คลิกที่นี่ >> ระบบรับสมัคร Gifted School | ...
# 175
# 26   MIdS : Multidisciplinary and Interdisciplinary...
# 133  Login Form  เลขบัตรประชาชน 13 หลัก        ดู P...
# 25   Home  Regulations  Knowledge  Lecturers  Struc...
# 171  Skip navigation              Home   Browse   C...
# 152  Skip to main content    Google Workspace Admin...
# 64   Skip to main content    Google Groups Help Sig...
# 71   Skip to main content    Google Play Help Sign ...
# 285  Ask a Question  mids@cmu.ac.th       ภาษาไทย  ...
# 236  Skip to main content    Google Docs Editors He...
# 153  Skip to main content    Google Docs Editors He...
# 8    Skip to main content    Gmail Help Sign in Goo...
# 290  Skip to main content         Microsoft     Sup...
# 253  Skip to main content    Google Account Help Si...
# 283  Skip to main content    Legal Help Sign in Goo...
# 130  Skip to main content    Google Account Help Si...
# 4    Skip to main content    Google Search Help Sig...
# 254  Privacy & Terms Sign in Overview Privacy Polic...
# 30   Privacy & Terms Sign in Overview Privacy Polic...
#
#                                              url_lists     score
# 214  [https://service.camt.cmu.ac.th/gifted/gifted/...  4.376591
# 175                                                 []  4.376591
# 26   [https://cmu.to/admission/, https://w3.grad.cm...  4.273990
# 133                                                 []  4.234285
# 25   [https://pandit.camt.cmu.ac.th/home/index, htt...  3.299405
# 171  [https://camt.cmu.ac.th/index.php/en/#content,...  3.056056
# 152  [https://camt.cmu.ac.th/index.php/en/#hcfe-con...  2.846137
# 64   [https://camt.cmu.ac.th/index.php/en/#hcfe-con...  2.663204
# 71   [https://camt.cmu.ac.th/index.php/en/#hcfe-con...  2.602380
# 285  [javascript:;, javascript:;, https://camt.cmu....  2.558554
# 236  [https://camt.cmu.ac.th/index.php/en/#hcfe-con...  2.468485
# 153  [https://camt.cmu.ac.th/index.php/en/#hcfe-con...  2.390795
# 8    [https://camt.cmu.ac.th/index.php/en/#hcfe-con...  2.311967
# 290  [javascript:void(0), https://www.microsoft.com...  2.200354
# 253  [https://camt.cmu.ac.th/index.php/en/#hcfe-con...  2.158669
# 283  [https://camt.cmu.ac.th/index.php/en/#hcfe-con...  2.028943
# 130  [https://camt.cmu.ac.th/index.php/en/#hcfe-con...  1.874566
# 4    [https://camt.cmu.ac.th/index.php/en/#hcfe-con...  1.706155
# 254  [https://camt.cmu.ac.th/, https://www.google.c...  1.576448
# 30   [https://camt.cmu.ac.th/, https://www.google.c...  1.576448
