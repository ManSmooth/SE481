# %%
import pandas as pd
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy import sparse
import numpy as np
import re
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import pickle
import os
import json
from pathlib import Path
from flask import Flask, request
from elasticsearch import Elasticsearch
import time
from sklearn.preprocessing import minmax_scale
import re


class PR:
    def __init__(self, alpha):
        self.crawled_folder = Path(os.path.abspath("")) / "crawled/"
        self.alpha = alpha
        self.url_extract()

    def url_extract(self):
        url_maps = {}
        all_urls = set([])
        for file in os.listdir(self.crawled_folder):
            if file.endswith(".json"):
                try:
                    j = json.load(open(os.path.join(self.crawled_folder, file)))
                    all_urls.add(j["url"])
                    all_urls.update(set(j["url_lists"]))
                    url_maps[j["url"]] = list(set(j["url_lists"]))
                except json.JSONDecodeError:
                    print(file)
        all_urls = list(all_urls)
        self.url_maps = url_maps
        self.all_urls = all_urls

    def pr_calc(self):
        url_maps, all_urls = self.url_maps, self.all_urls
        print(f"{len(all_urls)=}")
        url_idx = {v: i for (i, v) in enumerate(all_urls)}
        size = len(all_urls)
        url_matrix = sparse.lil_array((size, size), dtype=int)
        for url in url_maps:
            if len(url_maps[url]) > 0 and len(all_urls) > 0:
                url_matrix[
                    url_idx[url], [url_idx[sub_url] for sub_url in url_maps[url]]
                ] = 1
        # return url_matrix
        print(f"bytes@prepad: {url_matrix.data.nbytes}")
        rows = np.where(url_matrix.sum(1) == 0)[0]
        url_matrix[rows, :] = np.ones(size, int)
        print(f"bytes@postpad: {url_matrix.data.nbytes}")
        url_matrix = url_matrix * sparse.coo_array(1 / url_matrix.sum(axis=1)).T
        print(f"bytes@multiply: {url_matrix.data.nbytes}")

        x0 = np.repeat(1 / len(all_urls), len(all_urls)).T
        v = np.repeat(1 / len(all_urls), len(all_urls)).T

        prev_Px = x0
        Px = self.alpha * x0 @ url_matrix + (1 - self.alpha) * v
        i = 0
        while any(abs(np.asarray(prev_Px).flatten() - np.asarray(Px).flatten()) > 1e-8):
            i += 1
            prev_Px = Px
            Px = self.alpha * Px @ url_matrix + (1 - self.alpha) * v

        print(
            "Converged in {0} iterations: {1}".format(
                i, np.around(np.asarray(Px).flatten().astype(float), 5)
            )
        )

        self.pr_result = pd.Series(minmax_scale(Px), index=all_urls)


class BM25(object):
    def __init__(self, fitted_vectorizer: TfidfVectorizer, b=0.75, k1=1.6):
        self.fitted_vectorizer = fitted_vectorizer
        self.b = b
        self.k1 = k1

    def fit(self, X):
        """Fit IDF to documents X"""
        self.y = super(TfidfVectorizer, self.fitted_vectorizer).transform(X)
        self.avdl = self.y.sum(1).mean()

    def transform(self, q):
        """Calculate BM25 between query q and documents X"""
        b, k1, avdl = self.b, self.k1, self.avdl

        # apply CountVectorizer
        len_y = self.y.sum(1).A1
        (q,) = super(TfidfVectorizer, self.fitted_vectorizer).transform(q)
        assert sparse.isspmatrix_csr(q)

        # convert to csc for better column slicing
        y = self.y.tocsc()[:, q.indices]
        denom = y + (k1 * (1 - b + b * len_y / avdl))[:, None]
        idf = self.fitted_vectorizer._tfidf.idf_[None, q.indices] - 1.0
        numer = y.multiply(np.broadcast_to(idf, y.shape)) * (k1 + 1)
        return (numer / denom).sum(1).A1


def custom_preprocessor(s: str):
    lemmatizer = WordNetLemmatizer()
    s = re.sub(r"[^A-Za-z]", " ", s)
    s = re.sub(r"\s+", " ", s)
    s = re.sub(" +", " ", s)
    s = s.lower()
    s = word_tokenize(s)
    s = set(s).difference(set(stopwords.words("english")))
    s = [word for word in s if len(word) > 2]
    s = [lemmatizer.lemmatize(w) for w in s]
    s = " ".join(s)
    return s


class ManualIndexer:
    def __init__(self):
        self.crawled_folder = Path(os.path.abspath("")) / "crawled/"
        self.stored_file = "indexer/manual_indexer.pickle"
        if not Path(self.stored_file).parent.exists():
            Path.mkdir(Path(self.stored_file).parent)
        if os.path.isfile(self.stored_file):
            with open(self.stored_file, "rb") as f:
                cached_dict = pickle.load(f)
            self.__dict__.update(cached_dict)
        else:
            self.run_indexer()

    def run_indexer(self):
        documents = []
        for file in os.listdir(self.crawled_folder):
            if file.endswith(".json"):
                j = json.load(open(os.path.join(self.crawled_folder, file)))
                documents.append(j)
        self.documents = pd.DataFrame.from_dict(documents)
        tfidf_vectorizor = TfidfVectorizer(
            preprocessor=custom_preprocessor, stop_words=stopwords.words("english")
        )
        tfidf_vectorizor.fit(
            self.documents.apply(lambda s: " ".join(s[["title", "text"]]), axis=1)
        )
        self.bm25 = BM25(tfidf_vectorizor)
        self.bm25.fit(
            self.documents.apply(lambda s: " ".join(s[["title", "text"]]), axis=1)
        )
        self.pr = PR(0.8)
        self.pr.pr_calc()
        with open(self.stored_file, "wb") as f:
            pickle.dump(self.__dict__, f)

    def search(self, query):
        scores = minmax_scale(self.bm25.transform([query]))
        df = pd.DataFrame(scores, columns=["score"])
        result_df = self.documents.join(df)
        result_df["score"] = result_df.apply(
            lambda x: self.pr.pr_result[x["url"]] * x["score"], axis=1
        )
        result_df = result_df.sort_values("score", ascending=False).head(20)
        result_df["text_highlight"] = result_df["text"].apply(
            lambda x: [
                f"...{x[span[0] - 24: span[0]]}<b>{x[span[0] : span[1]]}</b>{x[span[1]: span[1] + 24]}..."
                for span in [
                    word_span
                    for word_spans in [
                        [
                            m.span()
                            for m in re.finditer(rf"\b{q_word}\b", x, re.IGNORECASE)
                        ]
                        for q_word in query.split()
                    ]
                    for word_span in word_spans
                ]
            ]
        )
        return result_df

# %%
manual_indexer = ManualIndexer()
# Out:
# len(all_urls)=7044
# bytes@prepad: 56352
# bytes@postpad: 56352
# bytes@multiply: 377642016
# Converged in 16 iterations: [0.00013 0.00014 0.00014 ... 0.00013 0.00014 0.00014]

# %%
query = "graduate school"
manual_indexer.search(query)
# Out:
#                                                    url  \
# 209  https://service.camt.cmu.ac.th/iso/home/lecturers
# 75                         https://www.grad.cmu.ac.th/
# 82             https://pandit.camt.cmu.ac.th/home/rule
# 19     https://accounts.google.com/TOS?loc=TH&hl=en-US
# 90                          https://w3.grad.cmu.ac.th/
# 303                            http://cmuir.cmu.ac.th/
# 342              https://service.camt.cmu.ac.th/gifted
# 213                        https://www.mids.cmu.ac.th/
# 144                          https://cmu.to/admission/
# 158                https://www.google.com/accounts/TOS
# 311               https://www.reg.cmu.ac.th/webreg/en/
# 308                    https://support.google.com/docs
# 194              https://m.wikihow.com/Disable-Cookies
# 16   https://service.camt.cmu.ac.th/iso/home/activi...
# 91                 https://www3.reg.cmu.ac.th/stdinfo/
# 347  https://service.camt.cmu.ac.th/gifted/gifted/i...
# 26   https://support.microsoft.com/en-us/help/40262...
# 285  https://support.google.com/groups/answer/81275...
# 227            https://policies.google.com/terms?hl=en
# 279  https://support.google.com/a?p=privpol_admin&h...
#
#                                                  title  \
# 209  ISO 30401:2018 - College of Arts, Media and Te...
# 75              Graduate School, Chiang Mai University
# 82        CAMT : College of Arts, Media and Technology
# 19   Google Terms of Service – Privacy & Terms – Go...
# 90              Graduate School, Chiang Mai University
# 303                  CMU Intellectual Repository: Home
# 342                                   Gift School 2023
# 213  MIdS : (M)ultidisciplinary and (I)nter(d)iscip...
# 144  การรับนักเรียน/บุคคล เข้าศึกษาต่อมหาวิทยาลัยเช...
# 158  Google Terms of Service – Privacy & Terms – Go...
# 311  Registration Office Chiang Mai University – Re...
# 308                           Google Docs Editors Help
# 194  How to Disable Cookies on Any Web Browser: Mob...
# 16   ISO 30401:2018 - College of Arts, Media and Te...
# 91   New Student Records System. Chiang Main Unversity
# 347                                   Gift School 2566
# 26   Browse InPrivate in Microsoft Edge - Microsoft...
# 285   Report abuse or legal issue - Google Groups Help
# 227  Google Terms of Service – Privacy & Terms – Go...
# 279  Who is my administrator? - Google Workspace Ad...
#
#                                                   text  \
# 209  Power BI  Home  Our Program  Context  manual  ...
# 75   MIdS : Multidisciplinary and Interdisciplinary...
# 82   Home  Regulations  Knowledge  Lecturers  Struc...
# 19   Privacy & Terms Sign in Overview Privacy Polic...
# 90
# 303  Skip navigation              Home   Browse   C...
# 342  monk4d  https://164.90.134.40/  https://159.22...
# 213  Ask a Question  mids@cmu.ac.th       ภาษาไทย  ...
# 144  การรับสมัครคัดเลือกบุคคลเข้าศึกษาต่อมหาวิทยาลั...
# 158  Privacy & Terms Sign in Overview Privacy Polic...
# 311  Skip to content                  Home  Current...
# 308  Skip to main content    Google Docs Editors He...
# 194  Skip to Content Quizzes PRO  Courses  Guides N...
# 16   Power BI  Home  Our Program  Context  manual  ...
# 91   à¸à¸±à¸à¸à¸¶à¸à¸à¸°à¹à¸à¸µà¸¢à¸à¸à¸£à...
# 347  monk4d  https://164.90.134.40/  https://159.22...
# 26   Skip to main content         Microsoft     Sup...
# 285  Skip to main content    Google Groups Help Sig...
# 227  Privacy & Terms Sign in Overview Privacy Polic...
# 279  Skip to main content    Google Workspace Admin...
#
#                                              url_lists     score  \
# 209  [https://www.camt.cmu.ac.th/index.php/th/index...  0.197608
# 75   [https://cmu.to/admission/, https://w3.grad.cm...  0.069104
# 82   [https://pandit.camt.cmu.ac.th/home/index, htt...  0.051672
# 19   [https://www.camt.cmu.ac.th/, https://www.goog...  0.034935
# 90                                                  []  0.032362
# 303  [https://www.camt.cmu.ac.th/index.php/th/#cont...  0.032304
# 342  [https://monk4dmain.com/, https://164.90.134.4...  0.030293
# 213  [javascript:;, javascript:;, https://www.camt....  0.016306
# 144  [https://admission.grad.cmu.ac.th/, https://ww...  0.015690
# 158  [https://www.camt.cmu.ac.th/, https://www.goog...  0.012498
# 311  [https://www.camt.cmu.ac.th/index.php/th/#cont...  0.012065
# 308  [https://www.camt.cmu.ac.th/index.php/th/#hcfe...  0.008048
# 194  [https://www.camt.cmu.ac.th/index.php/th/, htt...  0.004053
# 16   [https://www.camt.cmu.ac.th/index.php/th/index...  0.003422
# 91   [https://www.camt.cmu.ac.th/index.php/th/under...  0.002931
# 347  [https://monk4dmain.com/, https://164.90.134.4...  0.001916
# 26   [javascript:void(0), https://www.microsoft.com...  0.001224
# 285  [https://www.camt.cmu.ac.th/index.php/th/#hcfe...  0.000997
# 227  [https://www.camt.cmu.ac.th/, https://www.goog...  0.000793
# 279  [https://www.camt.cmu.ac.th/index.php/th/#hcfe...  0.000383
#
#                                         text_highlight
# 209                                                 []
# 75   [...rsity   Admission 2024  <b>Graduate</b> Sc...
# 82   [...iversity Regulations on <b>Graduate</b> St...
# 19   [...oration, non-profit, or <b>school</b>) and...
# 90                                                  []
# 303  [...se its collections.     <b>Graduate</b> Sc...
# 342  [... >> ระบบรับสมัคร Gifted <b>School</b> | Pr...
# 213  [... View More              <b>Graduate</b> Sc...
# 144  [...     ระดับบัณฑิตศึกษา / <b>Graduate</b> Le...
# 158  [...oration, non-profit, or <b>school</b>) and...
# 311  [...Undergraduate Students  <b>Graduate</b> St...
# 308  [...ocs Editors for work or <b>school</b> Goog...
# 194  [...ene Youth Personal Care <b>School</b> Stuf...
# 16   [... Ramin Keivani, Head of <b>School</b> of t...
# 91   [...à¸² Student Records for <b>Graduate</b> cl...
# 347  [... Profile         Gifted <b>School</b> 2023...
# 26   [...    How to buy for your <b>school</b>    E...
# 285  [... signed in to a work or <b>school</b> acco...
# 227  [...oration, non-profit, or <b>school</b>) and...
# 279  [... devices for a company, <b>school</b>, or ...

# %%
scores = minmax_scale(manual_indexer.bm25.transform([query]))
df = pd.DataFrame(scores, columns=["score"])
result_df = manual_indexer.documents.join(df)
result_df.set_index("url")["score"]
# Out:
# url
# https://www.reg.cmu.ac.th/webreg/th/links/                                                                                                                                                                           0.0
# https://www1.reg.cmu.ac.th/degreeverification/                                                                                                                                                                       0.0
# https://www.youtube.com/channel/UCBmwzQnSoj9b6HzNmFrg_yw                                                                                                                                                             0.0
# https://www.camt.cmu.ac.th/index.php/th/#dtm                                                                                                                                                                         0.0
# https://transparency.google/?hl=en_US                                                                                                                                                                                0.0
#                                                                                                                                                                                                                     ...
# https://docs.google.com/forms/d/e/1FAIpQLSed6GzXMcp02eiQybekUX0FNg8BR6e46SqIZE1Vxog-szqaiw/reportabuse?source=https://docs.google.com/forms/d/e/1FAIpQLSed6GzXMcp02eiQybekUX0FNg8BR6e46SqIZE1Vxog-szqaiw/viewform    0.0
# https://workspace.google.com/intl/en/features/?utm_source=formsforwork&utm_medium=et&utm_content=tryformsforwork&utm_campaign=globalnav                                                                              0.0
# https://support.google.com/blogger?p=privpol_blog&hl=en_US                                                                                                                                                           0.0
# https://www.youtube.com/feed/history?utm_source=pp&hl=en_US                                                                                                                                                          0.0
# https://www.camt.cmu.ac.th/index.php/th/?p=download_documents_list&key=5c5e5b8cb9463a6938cd508e6eef950f                                                                                                              0.0
# Name: score, Length: 357, dtype: float64
