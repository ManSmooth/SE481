# %%
import pandas as pd
from sklearn import model_selection, metrics
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import optuna
import lightgbm as lgb
import numpy as np
import joblib
from scipy.sparse import hstack
from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD
from pandarallel import pandarallel
import string
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from multiprocessing.pool import ThreadPool as Pool
import nltk
import optuna

pandarallel.initialize(nb_workers=8)

nltk.download("stopwords")
nltk.download("punkt")
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# [nltk_data] Downloading package stopwords to /home/amogus/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/amogus/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def initialize_worker(_stopwords, ps):
    global stemmer
    stemmer = ps
    global stopword_set
    stopword_set = _stopwords


def preprocess(text):
    cleaned_text = text.translate(
        str.maketrans(
            "!\#$%&'()*+,<=>?@[]^`{|}~\xa0",
            " " * 26,
        )
    )
    cleaned_text = cleaned_text.lower()
    cleaned_text = re.sub(r"\s+", " ", cleaned_text)
    cleaned_text = re.sub(r"\b\w*_\w+\b", "_term_with_underscore", cleaned_text)
    cleaned_text = re.sub(r"\b\w*-\w+\b", "_term_with_dash", cleaned_text)
    cleaned_text = re.sub(
        r"https?:\/\/(www\.)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)",
        "_weburl",
        cleaned_text,
    )
    cleaned_text = re.sub(r"\b[\w\\/]+?[\\/][\w\d_-]+?\b", "_path", cleaned_text)
    cleaned_text = re.sub(r"\b0[xb]?[a-f0-9]+\b", "_non_decimal_number", cleaned_text)
    cleaned_text = re.sub(
        r"\b\d+(px)?\s?[x*]\s?\d+(px)?\b", "_resolution", cleaned_text
    )
    cleaned_text = re.sub(r"\bv\d+(?:\.\d+)?\b", "_version", cleaned_text)
    cleaned_text = re.sub(
        r"\b\d+(?:\.\d+)?\b",
        "_number",
        cleaned_text,
    )
    cleaned_text = re.sub(r"\b(?!_)\w{15,}\b", "_very_long_term", cleaned_text)

    tokenized_text = word_tokenize(cleaned_text)

    sw_removed_text = [word for word in tokenized_text if word not in stopword_set]
    sw_removed_text = [word for word in sw_removed_text if len(word) > 1]
    stemmed_text = " ".join([stemmer.stem(w) for w in sw_removed_text])
    return stemmed_text

# %%
dataset = pd.read_json('resources/embold_train.json')
dataset.loc[dataset['label'] > 0, 'label'] = -1
dataset.loc[dataset['label'] == 0, 'label'] = 1
dataset.loc[dataset['label'] == -1, 'label'] = 0
stopwords_set = set(stopwords.words('english'))
ps = PorterStemmer()
pool = Pool(8, initializer=initialize_worker, initargs=(stopwords_set, ps, ))

cleaned_title = pool.map(preprocess, dataset.title)
cleaned_body = pool.map(preprocess, dataset.body)

# %%
y = dataset['label']
data_texts = pd.concat([pd.DataFrame([cleaned_title, cleaned_body], index=['title','body']).T, y.to_frame("label")], axis=1)
data_texts
# Out:
#                                                     title  \
# 0                              _term_with_dash piano roll
# 1                                   buggi behavior select
# 2                                       auto updat featur
# 3                               filter noisi endpoint log
# 4                        enabl pid pid alarm action _path
# ...                                                   ...
# 149995       suggest _very_long_term return random option
# 149996          decod display neurovault imag incorrectli
# 149997                         parser return error except
# 149998  errorexcept array string convers php artisan m...
# 149999                            ignor head code section
#
#                                                      body  label
# 0                    _term_with_dash piano roll would use      0
# 1       screenshot _term_with_dash_term_with_dash _num...      1
# 2       hi great job far saenzramiro auto updat featur...      0
# 3       think stop log request _term_with_underscor _t...      0
# 4       expect behavior alarm action pid pid enabl dis...      1
# ...                                                   ...    ...
# 149995  -- note anyth within bracket hidden preview is...      0
# 149996  note nicholst neurovault imag display properli...      1
# 149997  raml yaml raml _number titl test baseuri name ...      1
# 149998                              see occur branch rout      1
# 149999               process head insid quot code section      1
#
# [150000 rows x 3 columns]

# %%
data_texts = pd.read_parquet("resources/07/data_texts.parquet")
texts = data_texts[["title","body"]].agg(" ".join, axis=1)

data_fit, data_blindtest, y_fit, y_blindtest = model_selection.train_test_split(texts, data_texts["label"], test_size=0.2, stratify=data_texts["label"], random_state=0)

# %%
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1, 1))
try:
    tfidf_vectorizer = joblib.load("resources/07/tfidf_model.joblib")
except FileNotFoundError:
    tfidf_vectorizer.fit(texts)
    joblib.dump(tfidf_vectorizer, "resources/07/tfidf_model.joblib")
X_tfidf = tfidf_vectorizer.transform(texts)
X_tfidf_fit = tfidf_vectorizer.transform(data_fit)
X_tfidf_blindtest = tfidf_vectorizer.transform(data_blindtest)

# %%
count_vectorizer = CountVectorizer(ngram_range=(1, 1))
try:
    count_vectorizer = joblib.load("resources/07/count_vectorizer.joblib")
except FileNotFoundError:
    count_vectorizer.fit(texts)
    joblib.dump(count_vectorizer, "resources/07/count_vectorizer.joblib")
X_count = count_vectorizer.transform(texts)
X_count_fit = count_vectorizer.transform(data_fit)
X_count_blindtest = count_vectorizer.transform(data_blindtest)

# %%
data_texts.to_parquet("resources/07/data_texts.parquet")

# %%
lsa = TruncatedSVD(n_components=1000, random_state=0, n_iter=50)
try:
    lsa = joblib.load("resources/07/lsa_model.joblib")
except FileNotFoundError:
    lsa.fit(X_tfidf)
    joblib.dump(lsa, "resources/07/lsa_model.joblib")

# %%
X_lsa_fit = lsa.transform(X_tfidf_fit)
X_lsa_blindtest = lsa.transform(X_tfidf_blindtest)

# %%
lda = LatentDirichletAllocation(n_components=1000, max_iter=10, random_state=0, verbose=1)
try:
    lda = joblib.load("resources/07/lda_model.joblib")
except FileNotFoundError:
    lda.fit(X_tfidf)
    joblib.dump(lda, "resources/07/lda_model.joblib")

# %%
X_lda_fit = lsa.transform(X_count_fit)
X_lda_blindtest = lsa.transform(X_count_blindtest)

# %%
X_fit_with_lsa_lda = hstack([X_tfidf_fit, X_lsa_fit, X_lda_fit]).tocsr()
X_blindtest_with_lsa_lda = hstack(
    [X_tfidf_blindtest, X_lsa_blindtest, X_lda_blindtest]
).tocsr()

# %%
del count_vectorizer
del tfidf_vectorizer
del lda
del lsa
del data_texts
del texts
del X_tfidf_fit, X_lsa_fit, X_lda_fit
del X_tfidf_blindtest, X_lsa_blindtest, X_lda_blindtest

# %%
def objective_lda(trial):
    param = {
        "objective": "binary",
        "boosting_type": trial.suggest_categorical(
            "boosting_type", ["gbdt", "dart"]
        ),
        "reg_alpha ": trial.suggest_float("reg_alpha", 1e-8, 10.0, log=True),
        "reg_lambda ": trial.suggest_float("reg_lambda", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 8, 256),
        "learning_rate": trial.suggest_float("learning_rate", 1e-5, 1, log=True),
        "n_estimators": trial.suggest_int("n_estimators", 10, 1000),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        "random_state": 0,
        "verbose": -1,
    }
    model = lgb.LGBMClassifier(**param)
    model.fit(X_fit_with_lsa_lda, y_fit)
    preds = model.predict(X_blindtest_with_lsa_lda)
    pred_labels = np.rint(preds)
    accuracy = metrics.roc_auc_score(y_blindtest, pred_labels)
    return accuracy


study_lda = optuna.create_study(direction="maximize")
study_lda.optimize(objective_lda, n_trials= 16)
joblib.dump(study_lda, "resources/07/study_lsa_lda.pkl")
# Out:
# [I 2024-03-10 08:18:50,335] A new study created in memory with name: no-name-9a14f0b2-ae55-49b5-9685-d15510e931a1
# [I 2024-03-10 08:19:52,576] Trial 0 finished with value: 0.5 and parameters: {'boosting_type': 'dart', 'reg_alpha': 0.02470166041773878, 'reg_lambda': 9.679007242827921e-08, 'num_leaves': 26, 'learning_rate': 1.3336632801709667e-05, 'n_estimators': 104, 'min_child_samples': 57}. Best is trial 0 with value: 0.5.
# [I 2024-03-10 08:28:08,881] Trial 1 finished with value: 0.8013786126299902 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 0.000148994657042437, 'reg_lambda': 4.266339225586519e-06, 'num_leaves': 126, 'learning_rate': 0.2616043238826958, 'n_estimators': 498, 'min_child_samples': 49}. Best is trial 1 with value: 0.8013786126299902.
# [I 2024-03-10 08:32:05,222] Trial 2 finished with value: 0.8046624951043345 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 1.0966971432764787e-06, 'reg_lambda': 2.8840338865928714e-05, 'num_leaves': 133, 'learning_rate': 0.11111486817720409, 'n_estimators': 203, 'min_child_samples': 36}. Best is trial 2 with value: 0.8046624951043345.
# [I 2024-03-10 08:35:07,225] Trial 3 finished with value: 0.752992773812331 and parameters: {'boosting_type': 'dart', 'reg_alpha': 4.536530446967433e-05, 'reg_lambda': 6.889683800150176e-06, 'num_leaves': 16, 'learning_rate': 0.01734591282134749, 'n_estimators': 495, 'min_child_samples': 57}. Best is trial 2 with value: 0.8046624951043345.
# [I 2024-03-10 08:48:14,052] Trial 4 finished with value: 0.7615979789208924 and parameters: {'boosting_type': 'dart', 'reg_alpha': 1.7363287906840028, 'reg_lambda': 0.0437782584460959, 'num_leaves': 92, 'learning_rate': 0.007291483407986247, 'n_estimators': 697, 'min_child_samples': 28}. Best is trial 2 with value: 0.8046624951043345.
# [I 2024-03-10 08:49:59,077] Trial 5 finished with value: 0.6457337291021291 and parameters: {'boosting_type': 'dart', 'reg_alpha': 7.409197828502745, 'reg_lambda': 0.009619702308224565, 'num_leaves': 159, 'learning_rate': 0.004779610856553207, 'n_estimators': 58, 'min_child_samples': 43}. Best is trial 2 with value: 0.8046624951043345.
# [I 2024-03-10 08:51:27,862] Trial 6 finished with value: 0.5 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 0.16118765674624616, 'reg_lambda': 1.5014009526264053e-08, 'num_leaves': 231, 'learning_rate': 0.00022884507248041054, 'n_estimators': 39, 'min_child_samples': 61}. Best is trial 2 with value: 0.8046624951043345.
# [I 2024-03-10 09:10:55,361] Trial 7 finished with value: 0.78266146756278 and parameters: {'boosting_type': 'dart', 'reg_alpha': 0.016451059493861286, 'reg_lambda': 0.012889633629973592, 'num_leaves': 239, 'learning_rate': 0.01801807563835278, 'n_estimators': 549, 'min_child_samples': 29}. Best is trial 2 with value: 0.8046624951043345.
# [I 2024-03-10 09:21:40,153] Trial 8 finished with value: 0.6541089011883522 and parameters: {'boosting_type': 'dart', 'reg_alpha': 0.46838992960199405, 'reg_lambda': 1.1831854271101348e-05, 'num_leaves': 62, 'learning_rate': 0.0002573112241144703, 'n_estimators': 724, 'min_child_samples': 18}. Best is trial 2 with value: 0.8046624951043345.
# [I 2024-03-10 09:36:18,870] Trial 9 finished with value: 0.7977893688243353 and parameters: {'boosting_type': 'dart', 'reg_alpha': 1.7193668762373837, 'reg_lambda': 1.8262405744970203, 'num_leaves': 191, 'learning_rate': 0.6415344606039256, 'n_estimators': 532, 'min_child_samples': 54}. Best is trial 2 with value: 0.8046624951043345.
# [I 2024-03-10 09:40:04,787] Trial 10 finished with value: 0.8014332956523117 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 4.8168060401538607e-08, 'reg_lambda': 0.00021358577646501186, 'num_leaves': 133, 'learning_rate': 0.1414965640666194, 'n_estimators': 236, 'min_child_samples': 83}. Best is trial 2 with value: 0.8046624951043345.
# [I 2024-03-10 09:44:03,978] Trial 11 finished with value: 0.8046880655737483 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 4.0265484782050544e-08, 'reg_lambda': 0.0003194421700241233, 'num_leaves': 130, 'learning_rate': 0.10513429114466073, 'n_estimators': 257, 'min_child_samples': 90}. Best is trial 11 with value: 0.8046880655737483.
# [I 2024-03-10 09:49:52,714] Trial 12 finished with value: 0.8037185804543785 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 2.110078133916865e-08, 'reg_lambda': 0.00017071350463591066, 'num_leaves': 175, 'learning_rate': 0.13360319932405582, 'n_estimators': 305, 'min_child_samples': 100}. Best is trial 11 with value: 0.8046880655737483.
# [I 2024-03-10 09:54:09,776] Trial 13 finished with value: 0.8080835405452178 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 1.4706712924378142e-06, 'reg_lambda': 0.0010874103712632344, 'num_leaves': 101, 'learning_rate': 0.042586356887639024, 'n_estimators': 281, 'min_child_samples': 81}. Best is trial 13 with value: 0.8080835405452178.
# [I 2024-03-10 09:59:24,059] Trial 14 finished with value: 0.6678090729288004 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 1.4079644096255684e-06, 'reg_lambda': 0.004033843764798444, 'num_leaves': 84, 'learning_rate': 0.000786302042188761, 'n_estimators': 355, 'min_child_samples': 78}. Best is trial 13 with value: 0.8080835405452178.
# [I 2024-03-10 10:09:45,150] Trial 15 finished with value: 0.8087579195083453 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 3.1710419015464244e-06, 'reg_lambda': 0.6242299784986343, 'num_leaves': 98, 'learning_rate': 0.03533735917901179, 'n_estimators': 927, 'min_child_samples': 98}. Best is trial 15 with value: 0.8087579195083453.
# ['resources/07/study_lsa_lda.pkl']

# %%
study_lda.optimize(objective_lda, n_trials= 16)
# Out:
# [I 2024-03-10 10:20:59,970] Trial 16 finished with value: 0.8081622085329129 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 8.282486528834159e-06, 'reg_lambda': 3.953884755541324, 'num_leaves': 64, 'learning_rate': 0.023005216828739027, 'n_estimators': 871, 'min_child_samples': 73}. Best is trial 15 with value: 0.8087579195083453.
# [I 2024-03-10 10:30:46,831] Trial 17 finished with value: 0.7478342520823233 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 8.906977080104934e-06, 'reg_lambda': 3.209539542862226, 'num_leaves': 50, 'learning_rate': 0.0012202742785845336, 'n_estimators': 975, 'min_child_samples': 70}. Best is trial 15 with value: 0.8087579195083453.
# [I 2024-03-10 10:38:25,394] Trial 18 finished with value: 0.7845265600600737 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 0.0081972685581827, 'reg_lambda': 0.3439467909583704, 'num_leaves': 54, 'learning_rate': 0.9938281401412226, 'n_estimators': 936, 'min_child_samples': 100}. Best is trial 15 with value: 0.8087579195083453.
# [I 2024-03-10 10:46:59,376] Trial 19 finished with value: 0.8080678879095871 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 0.0004469422607235164, 'reg_lambda': 8.220363571707368, 'num_leaves': 75, 'learning_rate': 0.02982171425816265, 'n_estimators': 848, 'min_child_samples': 67}. Best is trial 15 with value: 0.8087579195083453.
# [I 2024-03-10 10:59:54,173] Trial 20 finished with value: 0.7830144952176813 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 0.0013595160587707984, 'reg_lambda': 0.21332843962323905, 'num_leaves': 109, 'learning_rate': 0.0035206234350795554, 'n_estimators': 801, 'min_child_samples': 89}. Best is trial 15 with value: 0.8087579195083453.
# [I 2024-03-10 11:10:00,677] Trial 21 finished with value: 0.8080934583790009 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 5.963680196502688e-07, 'reg_lambda': 0.356504335343361, 'num_leaves': 100, 'learning_rate': 0.0460241582680348, 'n_estimators': 885, 'min_child_samples': 77}. Best is trial 15 with value: 0.8087579195083453.
# [I 2024-03-10 11:16:15,570] Trial 22 finished with value: 0.8010770969893303 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 2.815748148426303e-07, 'reg_lambda': 0.30961428608922165, 'num_leaves': 34, 'learning_rate': 0.011055510240380742, 'n_estimators': 866, 'min_child_samples': 71}. Best is trial 15 with value: 0.8087579195083453.
# [I 2024-03-10 11:25:03,431] Trial 23 finished with value: 0.8093907042910149 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 1.5511984185716466e-05, 'reg_lambda': 1.2094987252700764, 'num_leaves': 73, 'learning_rate': 0.03988299408950851, 'n_estimators': 999, 'min_child_samples': 91}. Best is trial 23 with value: 0.8093907042910149.
# [I 2024-03-10 11:38:00,285] Trial 24 finished with value: 0.7585178505827739 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 1.0377875843770545e-05, 'reg_lambda': 1.63726516069741, 'num_leaves': 76, 'learning_rate': 0.0014264070218537154, 'n_estimators': 990, 'min_child_samples': 91}. Best is trial 23 with value: 0.8093907042910149.
# [I 2024-03-10 11:42:20,865] Trial 25 finished with value: 0.7956003274909197 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 2.7507896592811513e-05, 'reg_lambda': 0.06644612182529501, 'num_leaves': 44, 'learning_rate': 0.3385893881475854, 'n_estimators': 734, 'min_child_samples': 94}. Best is trial 23 with value: 0.8093907042910149.
# [I 2024-03-10 11:44:20,772] Trial 26 finished with value: 0.8038305102927886 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 6.118060909527922e-06, 'reg_lambda': 9.691627166388573, 'num_leaves': 10, 'learning_rate': 0.05199891961709864, 'n_estimators': 647, 'min_child_samples': 86}. Best is trial 23 with value: 0.8093907042910149.
# [I 2024-03-10 11:54:54,391] Trial 27 finished with value: 0.8010531120239566 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 0.00011061660409857973, 'reg_lambda': 0.08347308819303878, 'num_leaves': 68, 'learning_rate': 0.009332240009784836, 'n_estimators': 797, 'min_child_samples': 5}. Best is trial 23 with value: 0.8093907042910149.
# [I 2024-03-10 12:09:28,934] Trial 28 finished with value: 0.7745784330294903 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 2.24235112930919e-07, 'reg_lambda': 1.3825133700418661, 'num_leaves': 110, 'learning_rate': 0.0023248330472508396, 'n_estimators': 901, 'min_child_samples': 95}. Best is trial 23 with value: 0.8093907042910149.
# [I 2024-03-10 12:14:27,043] Trial 29 finished with value: 0.5 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 0.0006626649098898297, 'reg_lambda': 3.551780022980997e-07, 'num_leaves': 32, 'learning_rate': 2.0763037692139595e-05, 'n_estimators': 632, 'min_child_samples': 76}. Best is trial 23 with value: 0.8093907042910149.
# [I 2024-03-10 12:33:14,899] Trial 30 finished with value: 0.8104420621402888 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 0.0023101901707596284, 'reg_lambda': 0.8298144575340451, 'num_leaves': 164, 'learning_rate': 0.02468653793858504, 'n_estimators': 993, 'min_child_samples': 64}. Best is trial 30 with value: 0.8104420621402888.
# [I 2024-03-10 12:56:25,026] Trial 31 finished with value: 0.8103905838601762 and parameters: {'boosting_type': 'gbdt', 'reg_alpha': 0.0017819090059703405, 'reg_lambda': 0.7863875783829001, 'num_leaves': 206, 'learning_rate': 0.021888282399251356, 'n_estimators': 992, 'min_child_samples': 63}. Best is trial 30 with value: 0.8104420621402888.

# %%
study_lda = joblib.load("resources/07/study_lsa_lda.pkl")
study_lda

# %%
gbm_model = lgb.LGBMClassifier(**study_lda.best_params)
gbm_model.fit(
    X_fit_with_lsa_lda,
    y_fit,
    eval_set=[(X_blindtest_with_lsa_lda, y_blindtest)],
    eval_metric="AUC",
)
joblib.dump(gbm_model, "resources/07/gbm_model.joblib")
# Out:
# [LightGBM] [Info] Number of positive: 53462, number of negative: 66538
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.537915 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 924173
# [LightGBM] [Info] Number of data points in the train set: 120000, number of used features: 5595
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.445517 -> initscore=-0.218802
# [LightGBM] [Info] Start training from score -0.218802
# ['resources/07/gbm_model.joblib']

# %% [markdown]
# ## Final Accuracy

# %%
preds = gbm_model.predict(X_blindtest_with_lsa_lda)
score = metrics.roc_auc_score(y_blindtest, preds)
score
# Out:
# 0.8105475824942813

# %% [markdown]
# ## Flask Application Sample

# %%
import requests

data_texts = pd.read_parquet("resources/07/data_texts.parquet").sample(50)

# %%
def process_predict(s):
    predict = pd.json_normalize(requests.get(rf"http://127.0.0.1:5000/predict?title={s.title}&body={s.body}").json())[["predict_as", "bug_prob"]].iloc[0]
    s["predict_as"] = predict.predict_as
    s["bug_prob"] = predict.bug_prob
    return s


data_texts.apply(
    process_predict,
    axis=1,
)
# Out:
#                                                     title  \
# 95140                             implement new styleguid
# 142649                     add _very_long_term gift event
# 92559   nativ proxi enabl use node -- _term_with_dash ...
# 30484                              report invalid version
# 119538                             code coverag report ui
# 114208                        endless hang get job detail
# 88977                        reset graph data updat handl
# 42211                   exist signal metadata file format
# 107949           treemenu indic expand beyond scroll view
# 96552                   download modal warn larg download
# 94347   renderdoc assert captur cinder vulkan normalma...
# 102251               add programat support open accordion
# 55587                              add auto releas system
# 84129                               export data seen tabl
# 124881                           fix key bind arrow _path
# 51314                              edit gener form inform
# 17809                 add _very_long_term _very_long_term
# 147909                          save origin .lu file name
# 37123        captur inform _term_with_dash jsonapi object
# 148273                  add support request _number._numb
# 18079     stage platform standard rout work mcma question
# 147890                    show partial bucket option gone
# 51052                   instal path manag _very_long_term
# 110470    _number linebreak becom _number past text field
# 112431          useract commit honor initi popup lightbox
# 86567          extend return error none node driver onlin
# 101880  debian chroot packag instal i386 _term_with_un...
# 5463                                   creat project test
# 37103   _very_long_term seem work correctli word like ...
# 48807                   axiom librari work _path phonegap
# 145971     websocket error consol log run product environ
# 38889   _term_with_underscor function declar twice _te...
# 76897                      hamcrest matcher verifi header
# 32768   -o3 optim caus incorrect result osx clang _ter...
# 143623        stat return bow beam rifl _path weapon stat
# 124041                                send url past input
# 35882              featur request add support java server
# 147256               fallback call user authent fail ldap
# 129407  mgmt attribut releas polici option incorrectli...
# 44760                   quit pyfa use crest make app hang
# 46153                               filter restaur cuisin
# 95474                                       delet contact
# 128024                              view edit web app set
# 12687           quicklinkblock model rendor html href ...
# 39647                           display _number ilvl item
# 108676                             default read correctli
# 142273                         import relat rule refactor
# 13070                      temporari shapefil store locat
# 55473                    dogsonwalk alpha workout summari
# 43213    _term_with_dash see devic unless chang udev rule
#
#                                                      body  label predict_as  \
# 95140   new styleguid found _weburl one creat account ...      0    not bug
# 142649                                    new gifte creat      0    not bug
# 92559   environ instal apk _term_with_dash.apk _term_w...      0        bug
# 30484   modul version meta file report meta error per ...      0        bug
# 119538  would help develop could see test coverag repo...      0        bug
# 114208  seem happen job _term_with_dash mayb render ws...      1        bug
# 88977   present remov contest rate graph data need del...      0        bug
# 42211   issu dedic referenc alreadi exist metadata fil...      0    not bug
# 107949  _number go _weburl _number open treemenu _numb...      0    not bug
# 96552   download give warn gener file take certain amo...      0        bug
# 94347   t// might work e.g debug manag creation comman...      1        bug
# 102251               find way _very_long_term _weburl l62      0    not bug
# 55587   import releas new content quickli lot packag u...      0    not bug
# 84129   right download button download raw data possib...      1    not bug
# 124881                    may need key code bind engine.j      1        bug
# 51314   gener inform name slug etc edit mask appear us...      0    not bug
# 17809   _very_long_term overflow next line text width ...      0    not bug
# 147909  run program unpack file origin file name inste...      0    not bug
# 37123   version meta inform _weburl _term_with_dash_te...      0    not bug
# 148273  requir request version _number._numb quit ridi...      0    not bug
# 18079   standard rout work mcma question question temp...      1    not bug
# 147890  show partial bucket option never shown latest ...      1        bug
# 51052   exhibit ad /_path/_term_with_underscor path al...      1    not bug
# 110470  copi past text normal singl line break look no...      1        bug
# 112431  reproduc _number get paynow button use commit ...      1        bug
# 86567   bug report featur request bug report happen st...      1        bug
# 101880  hi fresh instal debian chroot ds3615x run dsm ...      0        bug
# 5463        set new project vs write unit test infer rule      0    not bug
# 37103   tri get current word cursor default option _ve...      1        bug
# 48807   build mobil app use phonegap debug browser app...      1        bug
# 145971  run product environ follow appear consol log _...      1        bug
# 38889   describ bug _term_with_underscor function decl...      1        bug
# 76897   take hamcrest matcher verifi header think requ...      0    not bug
# 32768   turn optim fix problem code initi special _ter...      1        bug
# 143623  investig _number notic return bow beam _term_w...      1        bug
# 124041                     imag _weburl send ctrl anywher      0        bug
# 35882   -- issu label necessari help organ issu label ...      0    not bug
# 147256  laravel version _number _term_with_dash versio...      0        bug
# 129407  click add new servic brows attribut releas tab...      1    not bug
# 44760   log use crest quit app make app hang forc quit...      1        bug
# 46153                       user abl filter restaur price      0    not bug
# 95474   contact tab way delet exist author data access...      1    not bug
# 128024      extens shall allow user view edit web app set      0    not bug
# 12687        _term_with_underscor block render _path pair      1    not bug
# 39647   hi use _number._term_with_dash version bagnon ...      1        bug
# 108676  x.hh.add _path gbar 1e3 x.hh.add _path gbar _n...      1    not bug
# 142273  current rule configur caus mani style base war...      0    not bug
# 13070   present _term_with_dash temporari shapefil sto...      0    not bug
# 55473   collect view workout summari fade due alpha ch...      1        bug
# 43213   instal udev rule file anoth project /_path/rul...      0        bug
#
#         bug_prob
# 95140   0.071387
# 142649  0.104231
# 92559   0.783775
# 30484   0.852607
# 119538  0.508291
# 114208  0.697286
# 88977   0.516365
# 42211   0.258212
# 107949  0.367572
# 96552   0.520923
# 94347   0.669498
# 102251  0.074364
# 55587   0.081967
# 84129   0.315434
# 124881  0.714987
# 51314   0.327120
# 17809   0.093196
# 147909  0.362183
# 37123   0.344542
# 148273  0.059137
# 18079   0.490293
# 147890  0.504170
# 51052   0.185219
# 110470  0.839069
# 112431  0.855065
# 86567   0.931455
# 101880  0.578027
# 5463    0.415070
# 37103   0.654260
# 48807   0.651371
# 145971  0.873640
# 38889   0.973391
# 76897   0.397139
# 32768   0.942170
# 143623  0.677587
# 124041  0.506953
# 35882   0.053565
# 147256  0.909470
# 129407  0.258903
# 44760   0.657667
# 46153   0.323951
# 95474   0.134261
# 128024  0.387192
# 12687   0.452260
# 39647   0.691432
# 108676  0.297141
# 142273  0.371760
# 13070   0.375943
# 55473   0.613824
# 43213   0.572994
